# %% [markdown]
# # Script to go through Karuk files for forced alignment
# - This script builds the metadata for the Karuk files, cleans up the transcriptions for the Montreal Forced Aligner (MFA), and creates a dictionary for the MFA
# - Karuk audio files and XML data gotten from http://linguistics.berkeley.edu/~karuk/

# %%
# For parsing xml
from bs4 import BeautifulSoup

# For navigating folders and creating things
import sys
import os
import glob
import re
import fnmatch

# For reading and handling dataframe
import pandas as pd

# For dealing with TextGrids
import audiolabel as al

# %% [markdown]
# ## Make csv file with file names, speakers, and sentences

# %%
### Do not run if already done!!!
### For next time around--write to csv with pandas
### Also, need to tag language so we can get rid of English sentences

# # Audio
# files = [f for f in sorted(glob.glob('../corpus/audio-sentences/*/*.wav', recursive = True))]

# # Metadata
# f = open('../corpus/karuk-texts.xml', 'r')
# contents = f.read()
# soup = BeautifulSoup(contents,'xml')

# # csv file write to
# with open('../data/audiodata_draft.csv', 'w') as w:
    
#     w.write(','.join(['audio', 'transcription']))
    
#     # Search in metadata for transcription of audio
#     for f in files:
#         f_ext = os.path.basename(f)
#         f_noext = f_ext[:-4]

#         # Search by the tag "s" for speaker and attribute "audio" that matches the filename
#         # Then find the text and remove all the extra whitespaces by splitting
#         try:
#             tran = soup.find("s", {"audio" : f_noext}).find('text-plain').string.split()
#             clean_tran = ' '.join(tran)
#         except AttributeError:
#             clean_tran = 'NA'
        
#         w.write('\n' + ';'.join([f_noext, clean_tran]))

# %%
# # FIX SOME
# df = pd.read_csv('../data/audiodata.csv', sep = ',')

# # 1782 is messed up
# to_fix = df.iloc[1782, :]['transcription'].split('\n')

# # Get rid of first one for now
# split_by_comma = [i.split(',') for i in to_fix][1:]

# # Rejoin the last ones
# rejoin = [[i[0], ','.join(i[1:])] for i in split_by_comma]

# # Make into df to attach
# sub_df = pd.DataFrame(rejoin, columns = ['audio', 'transcription'])

# # Add the ending to the last one
# sub_df.iloc[-1,-1] = sub_df.iloc[-1,-1] + " kiri xuus kun'uum."

# # Fix the messy row
# messy_row = pd.DataFrame({'audio':'LA78.1-002_013', 'transcription':' aakich ivaakirihti.'}, index =[0]) 

# sub_df = pd.concat([messy_row, sub_df]).reset_index(drop = True)

# # Now insert the sub_df in
# df_new = pd.concat([df.iloc[:1782, :], sub_df, df.iloc[1783:, :]]).reset_index(drop = True)

# df_new.to_csv('../data/audio_new.csv')

# %% [markdown]
# ## Read in the file we just wrote and fix commas

# %%
df = pd.read_csv('../data/audiodata.csv', sep = ',')

# Show NA's
df.loc[df.transcription.isnull()]

df['realtran'] = df[df.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)

# Get rid of English sentences
for i in [107, 123, 137, 139, 1108]:
    df.iloc[i, -1] = ''

# Drop all except the new combined transcription
df = df.drop(df.columns[range(1,len(df.columns)-1)], axis =1)
df = df.rename(columns={'realtran': 'transcription'})

df.to_csv('../data/audiodata_fixed.csv', index = False)

# %% [markdown]
# # Now read in file and fix for Montreal Forced Aligner

# %%
# Dictionary for replacing with MFA friendly characters
to_MFA = {
    # Other
    u'.': '',
    u',': '',
    u'?': '',
    u'!': '',
    u'"': '',
    u'-': '',
    u'’': '',
    # Tone
    u'́': '1',
    u'̂': '2',
    # Glottal
    u'\'': 'q',
    # Other unicode
    u'â': 'a2',
    u'á': 'a1',
    u'í': 'i1',
    u'î': 'i2',
    u'ú': 'u1',
    u'é': 'e1',
    u'ó': 'o1',
    u'ê': 'e2',
}

df = pd.read_csv('audiodata_fixed.csv', sep = ',')

df['transcription_mfa'] = df['transcription']

for orig, new in to_MFA.items():
    df['transcription_mfa'] = df['transcription_mfa'].str.replace(orig, new)
    
# Get rid of things inside ( ) and [ ]
for i in range(len(df)):
    tran = df.iloc[i, -1]
    
    if isinstance(tran, str):
        # Remove parentheses
        tran = re.sub("\(.*\)", "", tran)
        # Remove brackets
        tran = re.sub("\[.*\]", "", tran)
        # Remove all whitespace at side and in between
        tran = ' '.join(tran.split())

        # Now replace with new sentence
        df.iloc[i, -1] = tran

df.to_csv('../data/audio_metadata.csv', index = False)

# %% [markdown]
# ## Now modify empty textgrids by filling in with sentences
# Use the make_tg.sh shell script to make empty TextGrids. Praat doesn't like folders with spaces so make sure the path doesn't have any.

# %%
df = pd.read_csv('../data/audio_metadata.csv')

files = [f for f in sorted(glob.glob('../corpus/audio-sentences/*/*.wav', recursive = True))]

for f in files:
    # Find what the transcription should be
    audio = os.path.basename(f).replace('.wav', '')
    
    tran = df.loc[df['audio'] == audio]['transcription_mfa'].iloc[-1]
    
    if not isinstance(tran, str):
        tran = ''
    
    # Read in textgrid
    tg_file = f.replace('wav', 'TextGrid')
    tg = al.LabelManager(from_file=tg_file, from_type='praat')

    # Add in transcription
    tg.tier('transcription')[0].text = tran
    
    # Open TextGrid and replace with newly annotated one: 
    with open(tg_file, 'w', encoding='utf-8') as new_tg:
        new_tg.write(tg.as_string('praat_long'))

# %% [markdown]
# ## Create MFA dictionary

# %%
# MFA dictionary
# Create dictionary for MFA
tones = {
    '1': '',
    '2': ''
}

digraphs = {
    # Consonants
    'sh': 'SH',
    'ch': 'CH',
    'th': 'TH',
    # Vowels
    'ii': 'IY1',
    'uu': 'UW1',
    'aa': 'AA1',
    'ee': 'EY1',
    'oo': 'OW1',
}

monographs = {
    # Vowels
    'i': 'IH0',
    'u': 'UH0',
    'a': 'AH0',
    'e': 'EH0',
    'o': 'OW0',
    # Consonants
    'p': 'P',
    't': 'T',
    'k': 'K',
    'q': 'T',
    'm': 'M',
    'n': 'N',
    'f': 'F',
    's': 'SH',
    'x': 'HH',
    'h': 'HH',
    'v': 'V',
    'r': 'R',
    'y': 'Y',
    # Extra from English
    'b': 'B',
    'd': 'D',
    'g': 'G',
    'l': 'L',
    'w': 'W',
    'c': 'K',
    'j': 'JH',
    ':': ''
}

# Populate dictionary
df = pd.read_csv('../data/audiodata_mfa.csv')

array = df['transcription_mfa'].str.split()

words = set([x.lower() for l in array if isinstance(l, list) for x in l])

with open('../corpus/dictionary.txt', 'w') as dictionary:
    for w in sorted(words):
        pronunciation = w
        # Replace
        # Tone
        for tran, mfa in tones.items():
            pronunciation = pronunciation.replace(tran, mfa)
        # Digraphs
        for tran, mfa in digraphs.items():
            pronunciation = pronunciation.replace(tran, mfa + ' ')
        # Monographs
        for tran, mfa in monographs.items():
            pronunciation = pronunciation.replace(tran, ' ' + mfa + ' ')
        
        #print(w.strip())
        for x in pronunciation.split():
            
            # Check if any transcriptions have not been translated
            if x not in list(digraphs.values()) + list(monographs.values()):
                print(pronunciation, ' has the symbol ', x, ', Fix in the dictionary above')
        
        pronunciation = ' '.join(pronunciation.split())
        
        print(w, pronunciation)
            
        dictionary.write('  '.join([w, pronunciation])+'\n')
# Out:
# a AH0
# a1ah AA1 HH
# a1ahkuriheen AA1 HH K UH0 R IH0 HH EY1 N
# a1athik AA1 TH IH0 K
# a1hup AH0 HH UH0 P
# a1hupqaasvuuti AH0 HH UH0 P T AA1 SH V UW1 T IH0
# aachipvari AA1 CH IH0 P V AH0 R IH0
# aah AA1 HH
# aak AA1 K
# aakich AA1 K IH0 CH
# aama AA1 M AH0
# aamtih AA1 M T IH0 HH
# aapun AA1 P UH0 N
# aas AA1 SH
# aasak AA1 SH AH0 K
# aasaqeech AA1 SH AH0 T EY1 CH
# aasishrih AA1 SH IH0 SH R IH0 HH
# aav AA1 V
# aax AA1 HH
# aaxkunishichas AA1 HH K UH0 N IH0 SH IH0 CH AH0 SH
# aayas AA1 Y AH0 SH
# achpuus AH0 CH P UW1 SH
# achviiv AH0 CH V IY1 V
# ah AH0 HH
# ahapiimich AH0 HH AH0 P IY1 M IH0 CH
# ahup AH0 HH UH0 P
# ahupqasip AH0 HH UH0 P T AH0 SH IH0 P
# ahupqasipak AH0 HH UH0 P T AH0 SH IH0 P AH0 K
# akaay AH0 K AA1 Y
# akee AH0 K EY1
# aknap AH0 K N AH0 P
# akvaat AH0 K V AA1 T
# amayav AH0 M AH0 Y AH0 V
# amkiravasih AH0 M K IH0 R AH0 V AH0 SH IH0 HH
# anavikya2atich AH0 N AH0 V IH0 K Y AA1 T IH0 CH
# andrew AH0 N D R EH0 W
# apapiichyuupich AH0 P AH0 P IY1 CH Y UW1 P IH0 CH
# apapkam AH0 P AH0 P K AH0 M
# apim AH0 P IH0 M
# apmaan AH0 P M AA1 N
# apmaanak AH0 P M AA1 N AH0 K
# apus AH0 P UH0 SH
# apusqipaha AH0 P UH0 SH T IH0 P AH0 HH AH0
# apvuyipux AH0 P V UH0 Y IH0 P UH0 HH
# apxantinihich AH0 P HH AH0 N T IH0 N IH0 HH IH0 CH
# apxantinihichas AH0 P HH AH0 N T IH0 N IH0 HH IH0 CH AH0 SH
# apxantinihichqavansa AH0 P HH AH0 N T IH0 N IH0 HH IH0 CH T AH0 V AH0 N SH AH0
# aq AH0 T
# ara AH0 R AH0
# aramsiiprinti AH0 R AH0 M SH IY1 P R IH0 N T IH0
# aramsiiprintih AH0 R AH0 M SH IY1 P R IH0 N T IH0 HH
# ararachuupha AH0 R AH0 R AH0 CH UW1 P HH AH0
# ararahi AH0 R AH0 R AH0 HH IH0
# ararahih AH0 R AH0 R AH0 HH IH0 HH
# araraqavansa AH0 R AH0 R AH0 T AH0 V AH0 N SH AH0
# araraqish AH0 R AH0 R AH0 T IH0 SH
# araraqishpuk AH0 R AH0 R AH0 T IH0 SH P UH0 K
# arch AH0 R CH
# arihfakuheen AH0 R IH0 HH F AH0 K UH0 HH EY1 N
# arihish AH0 R IH0 HH IH0 SH
# arihishrih AH0 R IH0 HH IH0 SH R IH0 HH
# as AH0 SH
# asak AH0 SH AH0 K
# asakaamsa AH0 SH AH0 K AA1 M SH AH0
# asaxvuh AH0 SH AH0 HH V UH0 HH
# asimnaam AH0 SH IH0 M N AA1 M
# asip AH0 SH IH0 P
# astiip AH0 SH T IY1 P
# ata AH0 T AH0
# atafaat AH0 T AH0 F AA1 T
# ataychukinach AH0 T AH0 Y CH UH0 K IH0 N AH0 CH
# athiik AH0 TH IY1 K
# av AH0 V
# avahiv AH0 V AH0 HH IH0 V
# avansa AH0 V AH0 N SH AH0
# avansaxiich AH0 V AH0 N SH AH0 HH IY1 CH
# axak AH0 HH AH0 K
# axakyaan AH0 HH AH0 K Y AA1 N
# axaska AH0 HH AH0 SH K AH0
# axiich AH0 HH IY1 CH
# axkeemich AH0 HH K EY1 M IH0 CH
# axmay AH0 HH M AH0 Y
# axvahxuus AH0 HH V AH0 HH HH UW1 SH
# axvithirar AH0 HH V IH0 TH IH0 R AH0 R
# ayaa AH0 Y AA1
# ayaptanapapushiinvee AH0 Y AH0 P T AH0 N AH0 P AH0 P UH0 SH IY1 N V EY1
# ayiaye AH0 Y IH0 AH0 Y EH0
# ayii AH0 Y IY1
# ayiyihanijanee AH0 Y IH0 Y IH0 HH AH0 N IH0 JH AH0 N EY1
# ayiyiyiya AH0 Y IH0 Y IH0 Y IH0 Y AH0
# ayiyiyiyi AH0 Y IH0 Y IH0 Y IH0 Y IH0
# ayiyiyiyihi AH0 Y IH0 Y IH0 Y IH0 Y IH0 HH IH0
# ayiyiyiyihiya AH0 Y IH0 Y IH0 Y IH0 Y IH0 HH IH0 Y AH0
# ayiyiyiyiya AH0 Y IH0 Y IH0 Y IH0 Y IH0 Y AH0
# ayukii AH0 Y UH0 K IY1
# ayuqaach AH0 Y UH0 T AA1 CH
# biscuits B IH0 SH K UH0 IH0 T SH
# chakaqiimich CH AH0 K AH0 T IY1 M IH0 CH
# chakqiimich CH AH0 K T IY1 M IH0 CH
# chanaakat CH AH0 N AA1 K AH0 T
# chanchaksurak CH AH0 N CH AH0 K SH UH0 R AH0 K
# chareeaxay CH AH0 R EY1 AH0 HH AH0 Y
# chavura CH AH0 V UH0 R AH0
# chchchchch CH CH CH CH CH
# cheech CH EY1 CH
# cheemyaach CH EY1 M Y AA1 CH
# chemi CH EH0 M IH0
# chester CH EH0 SH T EH0 R
# chi CH IH0
# chikriish CH IH0 K R IY1 SH
# chimi CH IH0 M IH0
# chishii CH IH0 SH IY1
# chishiih CH IH0 SH IY1 HH
# chivchakar CH IH0 V CH AH0 K AH0 R
# chivchakarapiimich CH IH0 V CH AH0 K AH0 R AH0 P IY1 M IH0 CH
# choora CH OW1 R AH0
# chu CH UH0
# chuphuunish CH UH0 P HH UW1 N IH0 SH
# chuupha CH UW1 P HH AH0
# chuuphi CH UW1 P HH IH0
# chuvaarap CH UH0 V AA1 R AH0 P
# chuvniivkach CH UH0 V N IY1 V K AH0 CH
# clare K L AH0 R EH0
# cup K UH0 P
# ee EY1
# eeruun EY1 R UW1 N
# fa1at F AA1 T
# faat F AA1 T
# faatva F AA1 T V AH0
# fataak F AH0 T AA1 K
# fatamakeesh F AH0 T AH0 M AH0 K EY1 SH
# fiipha F IY1 P HH AH0
# furathfip F UH0 R AH0 TH F IH0 P
# gotthedeer G OW0 T TH EH0 D EY1 R
# ha HH AH0
# haa HH AA1
# haari HH AA1 R IH0
# hanainaa HH AH0 N AH0 IH0 N AA1
# hanijaaneeya HH AH0 N IH0 JH AA1 N EY1 Y AH0
# haqii HH AH0 T IY1
# harivari HH AH0 R IH0 V AH0 R IH0
# harivarihva HH AH0 R IH0 V AH0 R IH0 HH V AH0
# heavy HH EH0 AH0 V Y
# hinupa HH IH0 N UH0 P AH0
# hootah HH OW1 T AH0 HH
# hooy HH OW1 Y
# hooyva HH OW1 Y V AH0
# hruv HH R UH0 V
# hum HH UH0 M
# huuka HH UW1 K AH0
# huukava HH UW1 K AH0 V AH0
# huukeen HH UW1 K EY1 N
# huun HH UW1 N
# huut HH UW1 T
# huutheesh HH UW1 TH EY1 SH
# huutheeshara HH UW1 TH EY1 SH AH0 R AH0
# huutva HH UW1 T V AH0
# hyarih HH Y AH0 R IH0 HH
# hyiiva HH Y IY1 V AH0
# i IH0
# ichuphuunish IH0 CH UH0 P HH UW1 N IH0 SH
# ichuupha IH0 CH UW1 P HH AH0
# ichuupheesh IH0 CH UW1 P HH EY1 SH
# ichuuphitih IH0 CH UW1 P HH IH0 T IH0 HH
# if IH0 F
# ifikeesh IH0 F IH0 K EY1 SH
# ifuchtiimich IH0 F UH0 CH T IY1 M IH0 CH
# ifurathfiptih IH0 F UH0 R AH0 TH F IH0 P T IH0 HH
# ifuth IH0 F UH0 TH
# ifyaa IH0 F Y AA1
# ihyarih IH0 HH Y AH0 R IH0 HH
# ihyarihship IH0 HH Y AH0 R IH0 HH SH IH0 P
# ii IY1
# iihiya IY1 HH IH0 Y AH0
# iikam IY1 K AH0 M
# iim IY1 M
# iimkun IY1 M K UH0 N
# iimtihara IY1 M T IH0 HH AH0 R AH0
# iin IY1 N
# iinaak IY1 N AA1 K
# iish IY1 SH
# iiyeeshriheesh IY1 Y EY1 SH R IH0 HH EY1 SH
# ik IH0 K
# ikfuuksip IH0 K F UW1 K SH IH0 P
# ikfuuksipriv IH0 K F UW1 K SH IH0 P R IH0 V
# ikiich IH0 K IY1 CH
# ikmahachraam IH0 K M AH0 HH AH0 CH R AA1 M
# iknaknak IH0 K N AH0 K N AH0 K
# ikpihan IH0 K P IH0 HH AH0 N
# ikpur IH0 K P UH0 R
# ikreepux IH0 K R EY1 P UH0 HH
# ikriish IH0 K R IY1 SH
# ikriishrihi IH0 K R IY1 SH R IH0 HH IH0
# ikrivkir IH0 K R IH0 V K IH0 R
# ikrivkirak IH0 K R IH0 V K IH0 R AH0 K
# ikrivraam IH0 K R IH0 V R AA1 M
# ikshah IH0 K SH AH0 HH
# ikupaveenatih IH0 K UH0 P AH0 V EY1 N AH0 T IH0 HH
# ikuuntakoo IH0 K UW1 N T AH0 K OW1
# ikviithitih IH0 K V IY1 TH IH0 T IH0 HH
# ikxaram IH0 K HH AH0 R AH0 M
# ikxaramkunish IH0 K HH AH0 R AH0 M K UH0 N IH0 SH
# ikxiipship IH0 K HH IY1 P SH IH0 P
# ikxunanahaanich IH0 K HH UH0 N AH0 N AH0 HH AA1 N IH0 CH
# iky IH0 K Y
# ikyaakaam IH0 K Y AA1 K AA1 M
# ikyaan IH0 K Y AA1 N
# ikyaati IH0 K Y AA1 T IH0
# ikyaatih IH0 K Y AA1 T IH0 HH
# ikyaatihara IH0 K Y AA1 T IH0 HH AH0 R AH0
# ikyaavish IH0 K Y AA1 V IH0 SH
# ikyamiichvaheen IH0 K Y AH0 M IY1 CH V AH0 HH EY1 N
# ikyav IH0 K Y AH0 V
# ikyaveesh IH0 K Y AH0 V EY1 SH
# ikyavichvaan IH0 K Y AH0 V IH0 CH V AA1 N
# ikyivuni IH0 K Y IH0 V UH0 N IH0
# imaan IH0 M AA1 N
# imchakvaan IH0 M CH AH0 K V AA1 N
# imchax IH0 M CH AH0 HH
# imfir IH0 M F IH0 R
# imkunpaan IH0 M K UH0 N P AA1 N
# imnak IH0 M N AH0 K
# imniishtih IH0 M N IY1 SH T IH0 HH
# imnishaan IH0 M N IH0 SH AA1 N
# impaah IH0 M P AA1 HH
# imshirihraavish IH0 M SH IH0 R IH0 HH R AA1 V IH0 SH
# imusahatihara IH0 M UH0 SH AH0 HH AH0 T IH0 HH AH0 R AH0
# imusahitih IH0 M UH0 SH AH0 HH IH0 T IH0 HH
# imusakeem IH0 M UH0 SH AH0 K EY1 M
# imuusti IH0 M UW1 SH T IH0
# imuustih IH0 M UW1 SH T IH0 HH
# imxathakeem IH0 M HH AH0 TH AH0 K EY1 M
# inaa IH0 N AA1
# inainaya IH0 N AH0 IH0 N AH0 Y AH0
# ip IH0 P
# ipaathraa IH0 P AA1 TH R AA1
# ipaha IH0 P AH0 HH AH0
# ipahak IH0 P AH0 HH AH0 K
# ipaniichvari IH0 P AH0 N IY1 CH V AH0 R IH0
# iparamva IH0 P AH0 R AH0 M V AH0
# ipathraa IH0 P AH0 TH R AA1
# ipeen IH0 P EY1 N
# ipih IH0 P IH0 HH
# ipikrivruuhsur IH0 P IH0 K R IH0 V R UW1 HH SH UH0 R
# ipikrookti IH0 P IH0 K R OW1 K T IH0
# ipishriivpeesh IH0 P IH0 SH R IY1 V P EY1 SH
# ipit IH0 P IH0 T
# ipitih IH0 P IH0 T IH0 HH
# ipmahoonkoonatih IH0 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH
# ipmahoonkoonatihara IH0 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH AH0 R AH0
# ipmahoonkooneesh IH0 P M AH0 HH OW1 N K OW1 N EY1 SH
# ipshuunkinach IH0 P SH UW1 N K IH0 N AH0 CH
# ipshuunkinich IH0 P SH UW1 N K IH0 N IH0 CH
# ipshuunkunich IH0 P SH UW1 N K UH0 N IH0 CH
# iptaxatihi IH0 P T AH0 HH AH0 T IH0 HH IH0
# ipuunveesh IH0 P UW1 N V EY1 SH
# ipvoonvanaachheesh IH0 P V OW1 N V AH0 N AA1 CH HH EY1 SH
# ipvuunihi IH0 P V UW1 N IH0 HH IH0
# ipxatihi IH0 P HH AH0 T IH0 HH IH0
# ipyukukuh IH0 P Y UH0 K UH0 K UH0 HH
# ipyukukuhi IH0 P Y UH0 K UH0 K UH0 HH IH0
# ipyukukuhsuru IH0 P Y UH0 K UH0 K UH0 HH SH UH0 R UH0
# iqaamti IH0 T AA1 M T IH0
# iqaamtih IH0 T AA1 M T IH0 HH
# iqaapunmuti IH0 T AA1 P UH0 N M UH0 T IH0
# iqaapunmutih IH0 T AA1 P UH0 N M UH0 T IH0 HH
# iqafish IH0 T AH0 F IH0 SH
# iqaramsiiprimtih IH0 T AH0 R AH0 M SH IY1 P R IH0 M T IH0 HH
# iqarihfak IH0 T AH0 R IH0 HH F AH0 K
# iqasimchaaktiheesh IH0 T AH0 SH IH0 M CH AA1 K T IH0 HH EY1 SH
# iqavaheen IH0 T AH0 V AH0 HH EY1 N
# iqaveesh IH0 T AH0 V EY1 SH
# iqiinatih IH0 T IY1 N AH0 T IH0 HH
# iqiipma IH0 T IY1 P M AH0
# iqish IH0 T IH0 SH
# iqisheesh IH0 T IH0 SH EY1 SH
# iqitaptih IH0 T IH0 T AH0 P T IH0 HH
# iquufithva IH0 T UW1 F IH0 TH V AH0
# iquunupraveesh IH0 T UW1 N UH0 P R AH0 V EY1 SH
# ishaha IH0 SH AH0 HH AH0
# ishahak IH0 SH AH0 HH AH0 K
# ishahar IH0 SH AH0 HH AH0 R
# isharishriheesh IH0 SH AH0 R IH0 SH R IH0 HH EY1 SH
# ishavaas IH0 SH AH0 V AA1 SH
# ishimfir IH0 SH IH0 M F IH0 R
# ishimfirakuupha IH0 SH IH0 M F IH0 R AH0 K UW1 P HH AH0
# ishkaakatih IH0 SH K AA1 K AH0 T IH0 HH
# ishkih IH0 SH K IH0 HH
# ishnur IH0 SH N UH0 R
# ishriiv IH0 SH R IY1 V
# ishxaar IH0 SH HH AA1 R
# ishyaat IH0 SH Y AA1 T
# ithaan IH0 TH AA1 N
# ithaantakoo IH0 TH AA1 N T AH0 K OW1
# ithan IH0 TH AH0 N
# itharishrih IH0 TH AH0 R IH0 SH R IH0 HH
# itharishriheesh IH0 TH AH0 R IH0 SH R IH0 HH EY1 SH
# itheeshyav IH0 TH EY1 SH Y AH0 V
# ithiinatih IH0 TH IY1 N AH0 T IH0 HH
# ithiishriheesh IH0 TH IY1 SH R IH0 HH EY1 SH
# ithitiimtih IH0 TH IH0 T IY1 M T IH0 HH
# ithitiv IH0 TH IH0 T IH0 V
# ithivthaneenqaachip IH0 TH IH0 V TH AH0 N EY1 N T AA1 CH IH0 P
# ithivthaneenqipan IH0 TH IH0 V TH AH0 N EY1 N T IH0 P AH0 N
# ithvoon IH0 TH V OW1 N
# ithvuuyti IH0 TH V UW1 Y T IH0
# ithvuuytih IH0 TH V UW1 Y T IH0 HH
# ithyaruk IH0 TH Y AH0 R UH0 K
# ithyur IH0 TH Y UH0 R
# ithyuru IH0 TH Y UH0 R UH0
# itihaan IH0 T IH0 HH AA1 N
# itniivka IH0 T N IY1 V K AH0
# itxaariheen IH0 T HH AA1 R IH0 HH EY1 N
# ivaakirihti IH0 V AA1 K IH0 R IH0 HH T IH0
# ivaaram IH0 V AA1 R AH0 M
# ivaarameesh IH0 V AA1 R AH0 M EY1 SH
# ivishtaantih IH0 V IH0 SH T AA1 N T IH0 HH
# ivoonupuk IH0 V OW1 N UH0 P UH0 K
# ixraam IH0 HH R AA1 M
# ixrara IH0 HH R AH0 R AH0
# ixraratih IH0 HH R AH0 R AH0 T IH0 HH
# ixus IH0 HH UH0 SH
# ixuti IH0 HH UH0 T IH0
# ixutih IH0 HH UH0 T IH0 HH
# iyikihitih IH0 Y IH0 K IH0 HH IH0 T IH0 HH
# iyunyuunhitih IH0 Y UH0 N Y UW1 N HH IH0 T IH0 HH
# iyuunkuriheesh IH0 Y UW1 N K UH0 R IH0 HH EY1 SH
# iyuupha IH0 Y UW1 P HH AH0
# iyuupheesh IH0 Y UW1 P HH EY1 SH
# ka1an K AA1 N
# ka1ri K AH0 R IH0
# kaam K AA1 M
# kaan K AA1 N
# kaanimich K AA1 N IH0 M IH0 CH
# kaankan K AA1 N K AH0 N
# kaanvarih K AA1 N V AH0 R IH0 HH
# kaarim K AA1 R IH0 M
# kachakaach K AH0 CH AH0 K AA1 CH
# kachaqiich K AH0 CH AH0 T IY1 CH
# kahqarariik K AH0 HH T AH0 R AH0 R IY1 K
# kahtishraam K AH0 HH T IH0 SH R AA1 M
# kanapishaavsiprinih K AH0 N AH0 P IH0 SH AA1 V SH IH0 P R IH0 N IH0 HH
# kanikyav K AH0 N IH0 K Y AH0 V
# kanpakuriihvih K AH0 N P AH0 K UH0 R IY1 HH V IH0 HH
# kanpatum K AH0 N P AH0 T UH0 M
# kanpavan K AH0 N P AH0 V AH0 N
# kanthitiimtih K AH0 N TH IH0 T IY1 M T IH0 HH
# kanyuuphi K AH0 N Y UW1 P HH IH0
# kaqiruu K AH0 T IH0 R UW1
# kari K AH0 R IH0
# kariha K AH0 R IH0 HH AH0
# karihi K AH0 R IH0 HH IH0
# karu K AH0 R UH0
# karuk K AH0 R UH0 K
# karuma K AH0 R UH0 M AH0
# katiphiraquuth K AH0 T IH0 P HH IH0 R AH0 T UW1 TH
# kayla K AH0 Y L AH0
# kchkchkchkchkch K CH K CH K CH K CH K CH
# keech K EY1 CH
# keechas K EY1 CH AH0 SH
# keechikyav K EY1 CH IH0 K Y AH0 V
# keevniikich K EY1 V N IY1 K IH0 CH
# kfukuraa K F UH0 K UH0 R AA1
# kfukuvraa K F UH0 K UH0 V R AA1
# kfuuyshur K F UW1 Y SH UH0 R
# kfuy K F UH0 Y
# ki1ch K IH0 CH
# kich K IH0 CH
# kiiha K IY1 HH AH0
# kiihyarihship K IY1 HH Y AH0 R IH0 HH SH IH0 P
# kiikarihi K IY1 K AH0 R IH0 HH IH0
# kiikpaanvathap K IY1 K P AA1 N V AH0 TH AH0 P
# kiikpaatvi K IY1 K P AA1 T V IH0
# kiikpikaan K IY1 K P IH0 K AA1 N
# kiikpishnakarishukva K IY1 K P IH0 SH N AH0 K AH0 R IH0 SH UH0 K V AH0
# kiikpithxahi K IY1 K P IH0 TH HH AH0 HH IH0
# kiikqaanvathap K IY1 K T AA1 N V AH0 TH AH0 P
# kiikquumih K IY1 K T UW1 M IH0 HH
# kiikriishrih K IY1 K R IY1 SH R IH0 HH
# kiikviithinaa K IY1 K V IY1 TH IH0 N AA1
# kiikyaavunaa K IY1 K Y AA1 V UH0 N AA1
# kiikyav K IY1 K Y AH0 V
# kiimuustiheesh K IY1 M UW1 SH T IH0 HH EY1 SH
# kiipiyukukuhsuroo K IY1 P IH0 Y UH0 K UH0 K UH0 HH SH UH0 R OW1
# kiiptaxatihi K IY1 P T AH0 HH AH0 T IH0 HH IH0
# kiipyukukuhi K IY1 P Y UH0 K UH0 K UH0 HH IH0
# kiitkurihtih K IY1 T K UH0 R IH0 HH T IH0 HH
# kiivyiihfuruk K IY1 V Y IY1 HH F UH0 R UH0 K
# kinchifich K IH0 N CH IH0 F IH0 CH
# kinchuphunishkoo K IH0 N CH UH0 P HH UH0 N IH0 SH K OW1
# kinimuustih K IH0 N IH0 M UW1 SH T IH0 HH
# kinimuustiheesh K IH0 N IH0 M UW1 SH T IH0 HH EY1 SH
# kinpaxeepat K IH0 N P AH0 HH EY1 P AH0 T
# kipa K IH0 P AH0
# kiri K IH0 R IH0
# knaknak K N AH0 K N AH0 K
# koo K OW1
# kook K OW1 K
# koovu1ra K OW1 V UH0 R AH0
# koovura K OW1 V UH0 R AH0
# kpuuhsip K P UW1 HH SH IH0 P
# kriishrih K R IY1 SH R IH0 HH
# ktinvunaa K T IH0 N V UH0 N AA1
# ktir K T IH0 R
# ku1panakana K UH0 P AH0 N AH0 K AH0 N AH0
# kuchuuphinaatih K UH0 CH UW1 P HH IH0 N AA1 T IH0 HH
# kuha K UH0 HH AH0
# kukaam K UH0 K AA1 M
# kukupaveenahitih K UH0 K UH0 P AH0 V EY1 N AH0 HH IH0 T IH0 HH
# kukupaveenatih K UH0 K UH0 P AH0 V EY1 N AH0 T IH0 HH
# kukuum K UH0 K UW1 M
# kuma1qana K UH0 M AH0 T AH0 N AH0
# kumaam K UH0 M AA1 M
# kumapaah K UH0 M AH0 P AA1 HH
# kumaqaraar K UH0 M AH0 T AH0 R AA1 R
# kumaqaraaras K UH0 M AH0 T AH0 R AA1 R AH0 SH
# kumaqasip K UH0 M AH0 T AH0 SH IH0 P
# kumaqav K UH0 M AH0 T AH0 V
# kumaqavah K UH0 M AH0 T AH0 V AH0 HH
# kumaqavanihich K UH0 M AH0 T AH0 V AH0 N IH0 HH IH0 CH
# kumaqii K UH0 M AH0 T IY1
# kumaqish K UH0 M AH0 T IH0 SH
# kumaqpu1umpay K UH0 M AH0 T P UW1 M P AH0 Y
# kumateech K UH0 M AH0 T EY1 CH
# kumateechvanihich K UH0 M AH0 T EY1 CH V AH0 N IH0 HH IH0 CH
# kumeekrii K UH0 M EY1 K R IY1
# kumeethyur K UH0 M EY1 TH Y UH0 R
# kumnisheesh K UH0 M N IH0 SH EY1 SH
# kumusaheesh K UH0 M UH0 SH AH0 HH EY1 SH
# kumusahitiheesh K UH0 M UH0 SH AH0 HH IH0 T IH0 HH EY1 SH
# kun K UH0 N
# kuna K UH0 N AH0
# kuna2achqaa K UH0 N AA1 CH T AA1
# kunaachaa K UH0 N AA1 CH AA1
# kunaachqaa K UH0 N AA1 CH T AA1
# kunapasu1piich K UH0 N AH0 P AH0 SH UH0 P IY1 CH
# kunaveesh K UH0 N AH0 V EY1 SH
# kunchuphunishkoo K UH0 N CH UH0 P HH UH0 N IH0 SH K OW1
# kunchuuphitih K UH0 N CH UW1 P HH IH0 T IH0 HH
# kunfurathfip K UH0 N F UH0 R AH0 TH F IH0 P
# kuni2inak K UH0 N IY1 N AH0 K
# kunihmarathunanaatih K UH0 N IH0 HH M AH0 R AH0 TH UH0 N AH0 N AA1 T IH0 HH
# kunihmarathununaatih K UH0 N IH0 HH M AH0 R AH0 TH UH0 N UH0 N AA1 T IH0 HH
# kunihmaravarak K UH0 N IH0 HH M AH0 R AH0 V AH0 R AH0 K
# kunihmaravi K UH0 N IH0 HH M AH0 R AH0 V IH0
# kunikshaahtih K UH0 N IH0 K SH AA1 HH T IH0 HH
# kunikviithinaa K UH0 N IH0 K V IY1 TH IH0 N AA1
# kunikviithinaatih K UH0 N IH0 K V IY1 TH IH0 N AA1 T IH0 HH
# kunikvuuhvunaatih K UH0 N IH0 K V UW1 HH V UH0 N AA1 T IH0 HH
# kunikxiipshur K UH0 N IH0 K HH IY1 P SH UH0 R
# kunikyaatih K UH0 N IH0 K Y AA1 T IH0 HH
# kunikyamiichvunaa K UH0 N IH0 K Y AH0 M IY1 CH V UH0 N AA1
# kunimusahiti K UH0 N IH0 M UH0 SH AH0 HH IH0 T IH0
# kunimuusti K UH0 N IH0 M UW1 SH T IH0
# kunipe1er K UH0 N IH0 P EY1 R
# kunipeer K UH0 N IH0 P EY1 R
# kunipiip K UH0 N IH0 P IY1 P
# kunipitih K UH0 N IH0 P IH0 T IH0 HH
# kunipmahoonkoonatih K UH0 N IH0 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH
# kunish K UH0 N IH0 SH
# kunithtiitvunaa K UH0 N IH0 TH T IY1 T V UH0 N AA1
# kunithviripunih K UH0 N IH0 TH V IH0 R IH0 P UH0 N IH0 HH
# kunivyihuk K UH0 N IH0 V Y IH0 HH UH0 K
# kunivyiihma K UH0 N IH0 V Y IY1 HH M AH0
# kunivyiihshipreeheen K UH0 N IH0 V Y IY1 HH SH IH0 P R EY1 HH EY1 N
# kunivyiihshipreevish K UH0 N IH0 V Y IY1 HH SH IH0 P R EY1 V IH0 SH
# kunivyiiship K UH0 N IH0 V Y IY1 SH IH0 P
# kunixviiphinaatih K UH0 N IH0 HH V IY1 P HH IH0 N AA1 T IH0 HH
# kuniyaaram K UH0 N IH0 Y AA1 R AH0 M
# kuniyuunkiri K UH0 N IH0 Y UW1 N K IH0 R IH0
# kunkupeevyiihroovaheen K UH0 N K UH0 P EY1 V Y IY1 HH R OW1 V AH0 HH EY1 N
# kunkuphaanik K UH0 N K UH0 P HH AA1 N IH0 K
# kunkupheesh K UH0 N K UH0 P HH EY1 SH
# kunkuuntakoo K UH0 N K UW1 N T AH0 K OW1
# kunkuupha K UH0 N K UW1 P HH AH0
# kunmah K UH0 N M AH0 HH
# kunpaatva K UH0 N P AA1 T V AH0
# kunpaatvaheen K UH0 N P AA1 T V AH0 HH EY1 N
# kunpamfipishnihayaacha K UH0 N P AH0 M F IH0 P IH0 SH N IH0 HH AH0 Y AA1 CH AH0
# kunpamfipivrath K UH0 N P AH0 M F IH0 P IH0 V R AH0 TH
# kunpavyihish K UH0 N P AH0 V Y IH0 HH IH0 SH
# kunpavyihishrihanik K UH0 N P AH0 V Y IH0 HH IH0 SH R IH0 HH AH0 N IH0 K
# kunpavyihivrath K UH0 N P AH0 V Y IH0 HH IH0 V R AH0 TH
# kunpavyiihfuruk K UH0 N P AH0 V Y IY1 HH F UH0 R UH0 K
# kunpavyiihma K UH0 N P AH0 V Y IY1 HH M AH0
# kunpavyiihship K UH0 N P AH0 V Y IY1 HH SH IH0 P
# kunpavyiihshipreeheen K UH0 N P AH0 V Y IY1 HH SH IH0 P R EY1 HH EY1 N
# kunpavyiihshipreevish K UH0 N P AH0 V Y IY1 HH SH IH0 P R EY1 V IH0 SH
# kunpavyiishipeesh K UH0 N P AH0 V Y IY1 SH IH0 P EY1 SH
# kunpaxeepayaachha K UH0 N P AH0 HH EY1 P AH0 Y AA1 CH HH AH0
# kunpaxviipha K UH0 N P AH0 HH V IY1 P HH AH0
# kunpeetheep K UH0 N P EY1 TH EY1 P
# kunpihmarafakaheen K UH0 N P IH0 HH M AH0 R AH0 F AH0 K AH0 HH EY1 N
# kunpihmaravarak K UH0 N P IH0 HH M AH0 R AH0 V AH0 R AH0 K
# kunpiimshamvunaa K UH0 N P IY1 M SH AH0 M V UH0 N AA1
# kunpiineesh K UH0 N P IY1 N EY1 SH
# kunpiip K UH0 N P IY1 P
# kunpikaaraheen K UH0 N P IH0 K AA1 R AH0 HH EY1 N
# kunpishar K UH0 N P IH0 SH AH0 R
# kunpiyaaram K UH0 N P IH0 Y AA1 R AH0 M
# kunqaamvunaa K UH0 N T AA1 M V UH0 N AA1
# kunqahootiheen K UH0 N T AH0 HH OW1 T IH0 HH EY1 N
# kunqakakurihva K UH0 N T AH0 K AH0 K UH0 R IH0 HH V AH0
# kunqakunvunaatih K UH0 N T AH0 K UH0 N V UH0 N AA1 T IH0 HH
# kunqaraarahitih K UH0 N T AH0 R AA1 R AH0 HH IH0 T IH0 HH
# kunqaramsiipriv K UH0 N T AH0 R AH0 M SH IY1 P R IH0 V
# kunqarihishriihvaheen K UH0 N T AH0 R IH0 HH IH0 SH R IY1 HH V AH0 HH EY1 N
# kunqasu1uvish K UH0 N T AH0 SH UW1 V IH0 SH
# kunqaveesh K UH0 N T AH0 V EY1 SH
# kunqeeh K UH0 N T EY1 HH
# kunqichunvunaatih K UH0 N T IH0 CH UH0 N V UH0 N AA1 T IH0 HH
# kunqihukanveesh K UH0 N T IH0 HH UH0 K AH0 N V EY1 SH
# kunqiin K UH0 N T IY1 N
# kunqiinanik K UH0 N T IY1 N AH0 N IH0 K
# kunqiishvunaa K UH0 N T IY1 SH V UH0 N AA1
# kunqimpaha K UH0 N T IH0 M P AH0 HH AH0
# kunqipak K UH0 N T IH0 P AH0 K
# kunqipitih K UH0 N T IH0 P IH0 T IH0 HH
# kunqipmahoonkoonatih K UH0 N T IH0 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH
# kunqoonvishrihanik K UH0 N T OW1 N V IH0 SH R IH0 HH AH0 N IH0 K
# kunquufithvar K UH0 N T UW1 F IH0 TH V AH0 R
# kunquum K UH0 N T UW1 M
# kunsiitvunik K UH0 N SH IY1 T V UH0 N IH0 K
# kuntaarahiti K UH0 N T AA1 R AH0 HH IH0 T IH0
# kuntariheen K UH0 N T AH0 R IH0 HH EY1 N
# kunthaaniv K UH0 N TH AA1 N IH0 V
# kunvathiv K UH0 N V AH0 TH IH0 V
# kunvitish K UH0 N V IH0 T IH0 SH
# kunxus K UH0 N HH UH0 SH
# kunxutih K UH0 N HH UH0 T IH0 HH
# kunyichaachha K UH0 N Y IH0 CH AA1 CH HH AH0
# kunyootva K UH0 N Y OW1 T V AH0
# kunyunyuunhinaatih K UH0 N Y UH0 N Y UW1 N HH IH0 N AA1 T IH0 HH
# kupa1nakanakana K UH0 P AH0 N AH0 K AH0 N AH0 K AH0 N AH0
# kupanakanakana K UH0 P AH0 N AH0 K AH0 N AH0 K AH0 N AH0
# kupinivruuhtunva K UH0 P IH0 N IH0 V R UW1 HH T UH0 N V AH0
# kuqaveesh K UH0 T AH0 V EY1 SH
# kusaam K UH0 SH AA1 M
# kuthaaniv K UH0 TH AA1 N IH0 V
# kuuku K UW1 K UH0
# kuupha K UW1 P HH AH0
# kuusrah K UW1 SH R AH0 HH
# kuxrah K UH0 HH R AH0 HH
# kuxuriha K UH0 HH UH0 R IH0 HH AH0
# kuyaapkuh K UH0 Y AA1 P K UH0 HH
# kuyraak K UH0 Y R AA1 K
# kuyrakyaan K UH0 Y R AH0 K Y AA1 N
# kviip K V IY1 P
# kviitha K V IY1 TH AH0
# kviithi K V IY1 TH IH0
# kviripma K V IH0 R IH0 P M AH0
# kviripunih K V IH0 R IH0 P UH0 N IH0 HH
# kvurish K V UH0 R IH0 SH
# kvurishrih K V UH0 R IH0 SH R IH0 HH
# kxaramha K HH AH0 R AH0 M HH AH0
# kxaramkunish K HH AH0 R AH0 M K UH0 N IH0 SH
# kxip K HH IH0 P
# kxipish K HH IH0 P IH0 SH
# kxipma K HH IH0 P M AH0
# kxipuraa K HH IH0 P UH0 R AA1
# kyav K Y AH0 V
# kyiimkurih K Y IY1 M K UH0 R IH0 HH
# kyivish K Y IH0 V IH0 SH
# kyivishrih K Y IH0 V IH0 SH R IH0 HH
# kyivunih K Y IH0 V UH0 N IH0 HH
# kyutinih K Y UH0 T IH0 N IH0 HH
# leslie L EH0 SH L IH0 EH0
# line L IH0 N EH0
# lotsofwomenyouknowupthereinthereservation L OW0 T SH OW0 F W OW0 M EH0 N Y OW0 UH0 K N OW0 W UH0 P TH EH0 R EH0 IH0 N TH EH0 R EH0 SH EH0 R V AH0 T IH0 OW0 N
# lyn L Y N
# ma M AH0
# maa M AA1
# maahrav: M AA1 HH R AH0 V
# maakipiikunaachkiipiteesh M AA1 K IH0 P IY1 K UH0 N AA1 CH K IY1 P IH0 T EY1 SH
# maam M AA1 M
# maath M AA1 TH
# mah M AH0 HH
# mahiit M AH0 HH IY1 T
# mahnuuvanach M AH0 HH N UW1 V AH0 N AH0 CH
# mahqiit M AH0 HH T IY1 T
# mahqiitnihach M AH0 HH T IY1 T N IH0 HH AH0 CH
# mahqiitnihich M AH0 HH T IY1 T N IH0 HH IH0 CH
# man M AH0 N
# mana M AH0 N AH0
# mana2a M AH0 N AA1
# manaa M AH0 N AA1
# manava M AH0 N AH0 V AH0
# manqa1ta M AH0 N T AH0 T AH0
# manqata M AH0 N T AH0 T AH0
# maq M AH0 T
# maqninay M AH0 T N IH0 N AH0 Y
# maruk M AH0 R UH0 K
# matee M AH0 T EY1
# mchak M CH AH0 K
# medford M EH0 D F OW0 R D
# mikafih M IH0 K AH0 F IH0 HH
# mikrivraam M IH0 K R IH0 V R AA1 M
# mikxunanahaanich M IH0 K HH UH0 N AH0 N AH0 HH AA1 N IH0 CH
# miputiruh M IH0 P UH0 T IH0 R UH0 HH
# miqaraar M IH0 T AH0 R AA1 R
# miqaraaras M IH0 T AH0 R AA1 R AH0 SH
# miqaramah M IH0 T AH0 R AH0 M AH0 HH
# miqasimnaam M IH0 T AH0 SH IH0 M N AA1 M
# miqavaha M IH0 T AH0 V AH0 HH AH0
# miqavan M IH0 T AH0 V AH0 N
# miqifunih M IH0 T IH0 F UH0 N IH0 HH
# miqikxunanahaanich M IH0 T IH0 K HH UH0 N AH0 N AH0 HH AA1 N IH0 CH
# misupaah M IH0 SH UH0 P AA1 HH
# mit M IH0 T
# mithvaay M IH0 TH V AA1 Y
# mithvuy M IH0 TH V UH0 Y
# mitiik M IH0 T IY1 K
# mitikakvanaach M IH0 T IH0 K AH0 K V AH0 N AA1 CH
# mitipa M IH0 T IH0 P AH0
# mivaas M IH0 V AA1 SH
# mivu M IH0 V UH0
# mixvaah M IH0 HH V AA1 HH
# miyukukuh M IH0 Y UH0 K UH0 K UH0 HH
# mnakha M N AH0 K HH AH0
# mnish M N IH0 SH
# msakar M SH AH0 K AH0 R
# muchishiih M UH0 CH IH0 SH IY1 HH
# muchviiv M UH0 CH V IY1 V
# muhrooha M UH0 HH R OW1 HH AH0
# mukaqkukamich M UH0 K AH0 T K UH0 K AH0 M IH0 CH
# mukeechikyav M UH0 K EY1 CH IH0 K Y AH0 V
# mukrivraam M UH0 K R IH0 V R AA1 M
# mukunfithih M UH0 K UH0 N F IH0 TH IH0 HH
# mupiimich M UH0 P IY1 M IH0 CH
# muqaasravar M UH0 T AA1 SH R AH0 V AH0 R
# muqachviiv M UH0 T AH0 CH V IY1 V
# muqakah M UH0 T AH0 K AH0 HH
# muqam M UH0 T AH0 M
# muqifuni M UH0 T IH0 F UH0 N IH0
# muqifunih M UH0 T IH0 F UH0 N IH0 HH
# muqishkiit M UH0 T IH0 SH K IY1 T
# muquup M UH0 T UW1 P
# musara M UH0 SH AH0 R AH0
# musmusqiish M UH0 SH M UH0 SH T IY1 SH
# muteenva M UH0 T EY1 N V AH0
# muthvaay M UH0 TH V AA1 Y
# muthvuy M UH0 TH V UH0 Y
# muthyur M UH0 TH Y UH0 R
# mutikakvanaach M UH0 T IH0 K AH0 K V AH0 N AA1 CH
# muuk M UW1 K
# muusti M UW1 SH T IH0
# muustihinaa M UW1 SH T IH0 HH IH0 N AA1
# muveeniichva M UH0 V EY1 N IY1 CH V AH0
# muxuun M UH0 HH UW1 N
# muxvaah M UH0 HH V AA1 HH
# naa N AA1
# naapmanqanamahachhitih N AA1 P M AH0 N T AH0 N AH0 M AH0 HH AH0 CH HH IH0 T IH0 HH
# nachuphunishkoovish N AH0 CH UH0 P HH UH0 N IH0 SH K OW1 V IH0 SH
# nachuphuunish N AH0 CH UH0 P HH UW1 N IH0 SH
# nachuphuunisheesh N AH0 CH UH0 P HH UW1 N IH0 SH EY1 SH
# nafurathfip N AH0 F UH0 R AH0 TH F IH0 P
# nakishqiish N AH0 K IH0 SH T IY1 SH
# namah N AH0 M AH0 HH
# namahat N AH0 M AH0 HH AH0 T
# naniaunt N AH0 N IH0 AH0 UH0 N T
# nanifyiiv N AH0 N IH0 F Y IY1 V
# nanikeechikyav N AH0 N IH0 K EY1 CH IH0 K Y AH0 V
# nanikiit N AH0 N IH0 K IY1 T
# nanikrivkir N AH0 N IH0 K R IH0 V K IH0 R
# naniqasimnaam N AH0 N IH0 T AH0 SH IH0 M N AA1 M
# nanishpuk N AH0 N IH0 SH P UH0 K
# nanitaat N AH0 N IH0 T AA1 T
# nanithvuy N AH0 N IH0 TH V UH0 Y
# naniyeenipaxvuhich N AH0 N IH0 Y EY1 N IH0 P AH0 HH V UH0 HH IH0 CH
# naniyupsitanach N AH0 N IH0 Y UH0 P SH IH0 T AH0 N AH0 CH
# nanuqahup N AH0 N UH0 T AH0 HH UH0 P
# napar N AH0 P AH0 R
# napihniichha N AH0 P IH0 HH N IY1 CH HH AH0
# napivaxrah N AH0 P IH0 V AH0 HH R AH0 HH
# naqaapunmutihara N AH0 T AA1 P UH0 N M UH0 T IH0 HH AH0 R AH0
# naqaathva N AH0 T AA1 TH V AH0
# naqafish N AH0 T AH0 F IH0 SH
# naqakihi N AH0 T AH0 K IH0 HH IH0
# naqaxaska N AH0 T AH0 HH AH0 SH K AH0
# naqeehi N AH0 T EY1 HH IH0
# naqiik N AH0 T IY1 K
# nasayriihva N AH0 SH AH0 Y R IY1 HH V AH0
# nateeki N AH0 T EY1 K IH0
# nathitivara N AH0 TH IH0 T IH0 V AH0 R AH0
# navishtaanti N AH0 V IH0 SH T AA1 N T IH0
# navishtar N AH0 V IH0 SH T AH0 R
# naxaapka N AH0 HH AA1 P K AH0
# naxuriha N AH0 HH UH0 R IH0 HH AH0
# naxurihitihat N AH0 HH UH0 R IH0 HH IH0 T IH0 HH AH0 T
# nayaavaha N AH0 Y AA1 V AH0 HH AH0
# nayaavheesh N AH0 Y AA1 V HH EY1 SH
# nayikiha N AH0 Y IH0 K IH0 HH AH0
# nayikihitih N AH0 Y IH0 K IH0 HH IH0 T IH0 HH
# neefchak N EY1 F CH AH0 K
# neekfuuyshur N EY1 K F UW1 Y SH UH0 R
# neekshupih N EY1 K SH UH0 P IH0 HH
# neekshupiheet N EY1 K SH UH0 P IH0 HH EY1 T
# neektavihi N EY1 K T AH0 V IH0 HH IH0
# neekviitha N EY1 K V IY1 TH AH0
# neekvurish N EY1 K V UH0 R IH0 SH
# neekvurishrih N EY1 K V UH0 R IH0 SH R IH0 HH
# neekvurishrihat N EY1 K V UH0 R IH0 SH R IH0 HH AH0 T
# neekyaatihara N EY1 K Y AA1 T IH0 HH AH0 R AH0
# neemchak N EY1 M CH AH0 K
# neemchax N EY1 M CH AH0 HH
# neemchitatkoo N EY1 M CH IH0 T AH0 T K OW1
# neemusti N EY1 M UH0 SH T IH0
# neemustih N EY1 M UH0 SH T IH0 HH
# neemuustih N EY1 M UW1 SH T IH0 HH
# neep N EY1 P
# neepeentihat N EY1 P EY1 N T IH0 HH AH0 T
# neepeerat N EY1 P EY1 R AH0 T
# neepmahoonkoonatih N EY1 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH
# neepshaamkir N EY1 P SH AA1 M K IH0 R
# neepsharavriik N EY1 P SH AH0 R AH0 V R IY1 K
# neepsharavriiktih N EY1 P SH AH0 R AH0 V R IY1 K T IH0 HH
# neepsharavrik N EY1 P SH AH0 R AH0 V R IH0 K
# neepsharavrikeesh N EY1 P SH AH0 R AH0 V R IH0 K EY1 SH
# neepsheek N EY1 P SH EY1 K
# neepsheekti N EY1 P SH EY1 K T IH0
# neepsheektih N EY1 P SH EY1 K T IH0 HH
# neepshinvarihva N EY1 P SH IH0 N V AH0 R IH0 HH V AH0
# neetniivka N EY1 T N IY1 V K AH0
# neetniivkatih N EY1 T N IY1 V K AH0 T IH0 HH
# neexaychakish N EY1 HH AH0 Y CH AH0 K IH0 SH
# neexaychakisheesh N EY1 HH AH0 Y CH AH0 K IH0 SH EY1 SH
# neexra N EY1 HH R AH0
# neexrah N EY1 HH R AH0 HH
# neexrara N EY1 HH R AH0 R AH0
# neexviipha N EY1 HH V IY1 P HH AH0
# nichuphuunish N IH0 CH UH0 P HH UW1 N IH0 SH
# nichuphuunishti N IH0 CH UH0 P HH UW1 N IH0 SH T IH0
# nichuupha N IH0 CH UW1 P HH AH0
# nichuupheesh N IH0 CH UW1 P HH EY1 SH
# nichuuphitih N IH0 CH UW1 P HH IH0 T IH0 HH
# niheeratih N IH0 HH EY1 R AH0 T IH0 HH
# nihruuvti N IH0 HH R UW1 V T IH0
# nihyarih N IH0 HH Y AH0 R IH0 HH
# niinamich N IY1 N AH0 M IH0 CH
# nik N IH0 K
# nikfirip N IH0 K F IH0 R IH0 P
# nikfukuraa N IH0 K F UH0 K UH0 R AA1
# nikfuuksipriv N IH0 K F UW1 K SH IH0 P R IH0 V
# nikfuy N IH0 K F UH0 Y
# nikfuyfuuytih N IH0 K F UH0 Y F UW1 Y T IH0 HH
# nikiiheesh N IH0 K IY1 HH EY1 SH
# nikitnaaktih N IH0 K IH0 T N AA1 K T IH0 HH
# nikitnak N IH0 K IH0 T N AH0 K
# nikitnakeesh N IH0 K IH0 T N AH0 K EY1 SH
# nikmarakuriheeshva N IH0 K M AH0 R AH0 K UH0 R IH0 HH EY1 SH V AH0
# niknaknak N IH0 K N AH0 K N AH0 K
# niknaknakeesh N IH0 K N AH0 K N AH0 K EY1 SH
# nikpuhuthunavish N IH0 K P UH0 HH UH0 TH UH0 N AH0 V IH0 SH
# nikpuuhkar N IH0 K P UW1 HH K AH0 R
# nikpuuhmeesh N IH0 K P UW1 HH M EY1 SH
# nikraveesh N IH0 K R AH0 V EY1 SH
# nikrii N IH0 K R IY1
# nikriishrih N IH0 K R IY1 SH R IH0 HH
# nikriishriheesh N IH0 K R IY1 SH R IH0 HH EY1 SH
# nikshaahti N IH0 K SH AA1 HH T IH0
# nikshaahtih N IH0 K SH AA1 HH T IH0 HH
# nikshaatih N IH0 K SH AA1 T IH0 HH
# nikshah N IH0 K SH AH0 HH
# nikuniihkeesh N IH0 K UH0 N IY1 HH K EY1 SH
# nikupaveenatih N IH0 K UH0 P AH0 V EY1 N AH0 T IH0 HH
# nikupheen N IH0 K UH0 P HH EY1 N
# nikuuntakoo N IH0 K UW1 N T AH0 K OW1
# nikuupha N IH0 K UW1 P HH AH0
# nikvaareesh N IH0 K V AA1 R EY1 SH
# nikveeshrihat N IH0 K V EY1 SH R IH0 HH AH0 T
# nikviitha N IH0 K V IY1 TH AH0
# nikviithitih N IH0 K V IY1 TH IH0 T IH0 HH
# nikviithitiheesh N IH0 K V IY1 TH IH0 T IH0 HH EY1 SH
# nikviripeesh N IH0 K V IH0 R IH0 P EY1 SH
# nikvurishrih N IH0 K V UH0 R IH0 SH R IH0 HH
# nikxiipship N IH0 K HH IY1 P SH IH0 P
# nikxipmeesh N IH0 K HH IH0 P M EY1 SH
# nikyaakoopa N IH0 K Y AA1 K OW1 P AH0
# nikyaat N IH0 K Y AA1 T
# nikyaatih N IH0 K Y AA1 T IH0 HH
# nikyamiichva N IH0 K Y AH0 M IY1 CH V AH0
# nikyamiichveesh N IH0 K Y AH0 M IY1 CH V EY1 SH
# nikyamiichvutih N IH0 K Y AH0 M IY1 CH V UH0 T IH0 HH
# nikyivish N IH0 K Y IH0 V IH0 SH
# nimaahti N IH0 M AA1 HH T IH0
# nimah N IH0 M AH0 HH
# nimahat N IH0 M AH0 HH AH0 T
# nimaheesh N IH0 M AH0 HH EY1 SH
# nimaheeshi N IH0 M AH0 HH EY1 SH IH0
# nimnish N IH0 M N IH0 SH
# nimnisheesh N IH0 M N IH0 SH EY1 SH
# nimshakar N IH0 M SH AH0 K AH0 R
# nimuusti N IH0 M UW1 SH T IH0
# nimuustih N IH0 M UW1 SH T IH0 HH
# nimuustiheesh N IH0 M UW1 SH T IH0 HH EY1 SH
# ninipakuri N IH0 N IH0 P AH0 K UH0 R IH0
# ninithivthaaneen N IH0 N IH0 TH IH0 V TH AA1 N EY1 N
# niniyeeshiip N IH0 N IH0 Y EY1 SH IY1 P
# nipaatheesh N IH0 P AA1 TH EY1 SH
# nipaathkuriheesh N IH0 P AA1 TH K UH0 R IH0 HH EY1 SH
# nipaatveesh N IH0 P AA1 T V EY1 SH
# nipakuriihveesh N IH0 P AH0 K UH0 R IY1 HH V EY1 SH
# nipakuriihvutih N IH0 P AH0 K UH0 R IY1 HH V UH0 T IH0 HH
# nipasasip N IH0 P AH0 SH AH0 SH IH0 P
# nipath N IH0 P AH0 TH
# nipeesh N IH0 P EY1 SH
# nipikshaahtih N IH0 P IH0 K SH AA1 HH T IH0 HH
# nipikyaar N IH0 P IH0 K Y AA1 R
# nipikyaat N IH0 P IH0 K Y AA1 T
# nipikyaavish N IH0 P IH0 K Y AA1 V IH0 SH
# nipikyav N IH0 P IH0 K Y AH0 V
# nipipshinvahrihva N IH0 P IH0 P SH IH0 N V AH0 HH R IH0 HH V AH0
# nipipshinvarihva N IH0 P IH0 P SH IH0 N V AH0 R IH0 HH V AH0
# nipitap N IH0 P IH0 T AH0 P
# nipitapti N IH0 P IH0 T AH0 P T IH0
# nipitaptih N IH0 P IH0 T AH0 P T IH0 HH
# nipithxaheesh N IH0 P IH0 TH HH AH0 HH EY1 SH
# nipmaheesh N IH0 P M AH0 HH EY1 SH
# nipmahoonkoon N IH0 P M AH0 HH OW1 N K OW1 N
# nipmahoonkoonati N IH0 P M AH0 HH OW1 N K OW1 N AH0 T IH0
# nipmahoonkoonatih N IH0 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH
# nipmahoonkoonatihara N IH0 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH AH0 R AH0
# nipmahoonkooneesh N IH0 P M AH0 HH OW1 N K OW1 N EY1 SH
# nipthivkeevish N IH0 P TH IH0 V K EY1 V IH0 SH
# nipuunveesh N IH0 P UW1 N V EY1 SH
# nipvaaram N IH0 P V AA1 R AH0 M
# nipyukukuh N IH0 P Y UH0 K UH0 K UH0 HH
# nipyukukuhsuru N IH0 P Y UH0 K UH0 K UH0 HH SH UH0 R UH0
# niqaah N IH0 T AA1 HH
# niqaamtih N IH0 T AA1 M T IH0 HH
# niqaapunma N IH0 T AA1 P UH0 N M AH0
# niqaapunmuti N IH0 T AA1 P UH0 N M UH0 T IH0
# niqaapunmutih N IH0 T AA1 P UH0 N M UH0 T IH0 HH
# niqaasish N IH0 T AA1 SH IH0 SH
# niqaasishriheesh N IH0 T AA1 SH IH0 SH R IH0 HH EY1 SH
# niqaayti N IH0 T AA1 Y T IH0
# niqaaytih N IH0 T AA1 Y T IH0 HH
# niqafish N IH0 T AH0 F IH0 SH
# niqahoo N IH0 T AH0 HH OW1
# niqahootih N IH0 T AH0 HH OW1 T IH0 HH
# niqahoovish N IH0 T AH0 HH OW1 V IH0 SH
# niqakihtih N IH0 T AH0 K IH0 HH T IH0 HH
# niqam N IH0 T AH0 M
# niqapimtih N IH0 T AH0 P IH0 M T IH0 HH
# niqapiv N IH0 T AH0 P IH0 V
# niqaramsiiprimtih N IH0 T AH0 R AH0 M SH IY1 P R IH0 M T IH0 HH
# niqaramsiiprintih N IH0 T AH0 R AH0 M SH IY1 P R IH0 N T IH0 HH
# niqaramsiiprivtih N IH0 T AH0 R AH0 M SH IY1 P R IH0 V T IH0 HH
# niqaramsip N IH0 T AH0 R AH0 M SH IH0 P
# niqarihfakeesh N IH0 T AH0 R IH0 HH F AH0 K EY1 SH
# niqarihishrih N IH0 T AH0 R IH0 HH IH0 SH R IH0 HH
# niqav N IH0 T AH0 V
# niqavat N IH0 T AH0 V AH0 T
# niqaveesh N IH0 T AH0 V EY1 SH
# niqay N IH0 T AH0 Y
# niqayti N IH0 T AH0 Y T IH0
# niqeechipreevish N IH0 T EY1 CH IH0 P R EY1 V IH0 SH
# niqichunvutih N IH0 T IH0 CH UH0 N V UH0 T IH0 HH
# niqihroovish N IH0 T IH0 HH R OW1 V IH0 SH
# niqiikat N IH0 T IY1 K AH0 T
# niqiikeesh N IH0 T IY1 K EY1 SH
# niqiin N IH0 T IY1 N
# niqimfireesh N IH0 T IH0 M F IH0 R EY1 SH
# niqipak N IH0 T IH0 P AH0 K
# niqipakeesh N IH0 T IH0 P AH0 K EY1 SH
# niqiripeesh N IH0 T IH0 R IH0 P EY1 SH
# niqish N IH0 T IH0 SH
# niqisheesh N IH0 T IH0 SH EY1 SH
# niqitap N IH0 T IH0 T AH0 P
# niqitaptih N IH0 T IH0 T AH0 P T IH0 HH
# niqitxaarihva N IH0 T IH0 T HH AA1 R IH0 HH V AH0
# niqitxaarihvutih N IH0 T IH0 T HH AA1 R IH0 HH V UH0 T IH0 HH
# niquufithveesh N IH0 T UW1 F IH0 TH V EY1 SH
# niquufithvutih N IH0 T UW1 F IH0 TH V UH0 T IH0 HH
# niquum N IH0 T UW1 M
# niquumeesh N IH0 T UW1 M EY1 SH
# nishchur N IH0 SH CH UH0 R
# nishkaakuriheesh N IH0 SH K AA1 K UH0 R IH0 HH EY1 SH
# nishxaar N IH0 SH HH AA1 R
# nishxaareesh N IH0 SH HH AA1 R EY1 SH
# nitaayvaar N IH0 T AA1 Y V AA1 R
# nitakararih N IH0 T AH0 K AH0 R AH0 R IH0 HH
# nitakav N IH0 T AH0 K AH0 V
# nitakireesh N IH0 T AH0 K IH0 R EY1 SH
# nitatuyshureesh N IH0 T AH0 T UH0 Y SH UH0 R EY1 SH
# nitatuyshuru N IH0 T AH0 T UH0 Y SH UH0 R UH0
# nithaaniv N IH0 TH AA1 N IH0 V
# nithafipeesh N IH0 TH AH0 F IH0 P EY1 SH
# nitharampuuktih N IH0 TH AH0 R AH0 M P UW1 K T IH0 HH
# nitharishrih N IH0 TH AH0 R IH0 SH R IH0 HH
# nithiinatih N IH0 TH IY1 N AH0 T IH0 HH
# nithitiimti N IH0 TH IH0 T IY1 M T IH0
# nithitiimtih N IH0 TH IH0 T IY1 M T IH0 HH
# nithitiv N IH0 TH IH0 T IH0 V
# nithriish N IH0 TH R IY1 SH
# nithvuuytih N IH0 TH V UW1 Y T IH0 HH
# nithxuunatih N IH0 TH HH UW1 N AH0 T IH0 HH
# nithyuritih N IH0 TH Y UH0 R IH0 T IH0 HH
# nithyurutih N IH0 TH Y UH0 R UH0 T IH0 HH
# nitxaarih N IH0 T HH AA1 R IH0 HH
# nivaaram N IH0 V AA1 R AH0 M
# nivaaramat N IH0 V AA1 R AH0 M AH0 T
# nivaarameesh N IH0 V AA1 R AH0 M EY1 SH
# nivishtaantih N IH0 V IH0 SH T AA1 N T IH0 HH
# nivoonsip N IH0 V OW1 N SH IH0 P
# nivoonupuk N IH0 V OW1 N UH0 P UH0 K
# nixaapka N IH0 HH AA1 P K AH0
# nixaapkeesh N IH0 HH AA1 P K EY1 SH
# nixapkoovish N IH0 HH AH0 P K OW1 V IH0 SH
# nixrareesh N IH0 HH R AH0 R EY1 SH
# nixuti N IH0 HH UH0 T IH0
# niyikiha N IH0 Y IH0 K IH0 HH AH0
# niyikihatih N IH0 Y IH0 K IH0 HH AH0 T IH0 HH
# niyikiheen N IH0 Y IH0 K IH0 HH EY1 N
# niyikiheesh N IH0 Y IH0 K IH0 HH EY1 SH
# niykareesh N IH0 Y K AH0 R EY1 SH
# niyufishhat N IH0 Y UH0 F IH0 SH HH AH0 T
# niyuuhveesh N IH0 Y UW1 HH V EY1 SH
# now N OW0 W
# nu N UH0
# nuchuphunishkoovish N UH0 CH UH0 P HH UH0 N IH0 SH K OW1 V IH0 SH
# nuchuupha N UH0 CH UW1 P HH AH0
# nuchuupheesh N UH0 CH UW1 P HH EY1 SH
# nuchuuphi N UH0 CH UW1 P HH IH0
# nuchuuphitih N UH0 CH UW1 P HH IH0 T IH0 HH
# nuhyarih N UH0 HH Y AH0 R IH0 HH
# nukfukuraa N UH0 K F UH0 K UH0 R AA1
# nukookaneesh N UH0 K OW1 K AH0 N EY1 SH
# nukrii N UH0 K R IY1
# nukviithi N UH0 K V IY1 TH IH0
# nukyaari N UH0 K Y AA1 R IH0
# nukyaati N UH0 K Y AA1 T IH0
# nukyav N UH0 K Y AH0 V
# numah N UH0 M AH0 HH
# numaheesh N UH0 M AH0 HH EY1 SH
# numniishti N UH0 M N IY1 SH T IH0
# numnisheesh N UH0 M N IH0 SH EY1 SH
# numsakar N UH0 M SH AH0 K AH0 R
# nupar N UH0 P AH0 R
# nupareesh N UH0 P AH0 R EY1 SH
# nuparty N UH0 P AH0 R T Y
# nupaxviipha N UH0 P AH0 HH V IY1 P HH AH0
# nupaxviiphat N UH0 P AH0 HH V IY1 P HH AH0 T
# nupiini N UH0 P IY1 N IH0
# nupitap N UH0 P IH0 T AH0 P
# nupmah N UH0 P M AH0 HH
# nupmaheesh N UH0 P M AH0 HH EY1 SH
# nupuunvi N UH0 P UW1 N V IH0
# nuqaamtih N UH0 T AA1 M T IH0 HH
# nuqaasishrihinaa N UH0 T AA1 SH IH0 SH R IH0 HH IH0 N AA1
# nuqafish N UH0 T AH0 F IH0 SH
# nuqakunvar N UH0 T AH0 K UH0 N V AH0 R
# nuqam N UH0 T AH0 M
# nuqamvunaavish N UH0 T AH0 M V UH0 N AA1 V IH0 SH
# nuqapimtih N UH0 T AH0 P IH0 M T IH0 HH
# nuqapunmiik N UH0 T AH0 P UH0 N M IY1 K
# nuqava N UH0 T AH0 V AH0
# nuqavat N UH0 T AH0 V AH0 T
# nuqaveesh N UH0 T AH0 V EY1 SH
# nuqihukanveesh N UH0 T IH0 HH UH0 K AH0 N V EY1 SH
# nuqitapeesh N UH0 T IH0 T AH0 P EY1 SH
# nuquufithvan N UH0 T UW1 F IH0 TH V AH0 N
# nuquufithvar N UH0 T UW1 F IH0 TH V AH0 R
# nuquumat N UH0 T UW1 M AH0 T
# nusxay N UH0 SH HH AH0 Y
# nusxayvunaa N UH0 SH HH AH0 Y V UH0 N AA1
# nuteekeesh N UH0 T EY1 K EY1 SH
# nuthitiv N UH0 TH IH0 T IH0 V
# nuthtiitvunaa N UH0 TH T IY1 T V UH0 N AA1
# nuu N UW1
# nuvyihuk N UH0 V Y IH0 HH UH0 K
# nuvyiihshipreevish N UH0 V Y IY1 HH SH IH0 P R EY1 V IH0 SH
# nuvyiiship N UH0 V Y IY1 SH IH0 P
# nuvyiishipreevish N UH0 V Y IY1 SH IH0 P R EY1 V IH0 SH
# nuvyiishipriv N UH0 V Y IY1 SH IH0 P R IH0 V
# oh OW0 HH
# oo OW1
# ook OW1 K
# orleans OW0 R L EH0 AH0 N SH
# pa P AH0
# pa1pirish P AH0 P IH0 R IH0 SH
# pa1y P AH0 Y
# paachur P AA1 CH UH0 R
# paachviiv P AA1 CH V IY1 V
# paah P AA1 HH
# paahak P AA1 HH AH0 K
# paanpay P AA1 N P AH0 Y
# paastaah P AA1 SH T AA1 HH
# paathkurihi P AA1 TH K UH0 R IH0 HH IH0
# paathraa P AA1 TH R AA1
# paatvi P AA1 T V IH0
# paaxiich P AA1 HH IY1 CH
# paaxiitichas P AA1 HH IY1 T IH0 CH AH0 SH
# pacake P AH0 K AH0 K EH0
# pachiipich P AH0 CH IY1 P IH0 CH
# pachikinquruh P AH0 CH IH0 K IH0 N T UH0 R UH0 HH
# pachinim P AH0 CH IH0 N IH0 M
# pachishihaxvaah P AH0 CH IH0 SH IH0 HH AH0 HH V AA1 HH
# pachishii P AH0 CH IH0 SH IY1
# pachishiih P AH0 CH IH0 SH IY1 HH
# pachivchakar P AH0 CH IH0 V CH AH0 K AH0 R
# pachuufish P AH0 CH UW1 F IH0 SH
# pafipi P AH0 F IH0 P IH0
# pahaknah P AH0 HH AH0 K N AH0 HH
# pahupqasip P AH0 HH UH0 P T AH0 SH IH0 P
# pajuice P AH0 JH UH0 IH0 K EH0
# pakaan P AH0 K AA1 N
# pakaas P AH0 K AA1 SH
# pakachakaach P AH0 K AH0 CH AH0 K AA1 CH
# pakahqarahsas P AH0 K AH0 HH T AH0 R AH0 HH SH AH0 SH
# pakaruk P AH0 K AH0 R UH0 K
# pakeech P AH0 K EY1 CH
# pakeechas P AH0 K EY1 CH AH0 SH
# pakihara P AH0 K IH0 HH AH0 R AH0
# pakoovura P AH0 K OW1 V UH0 R AH0
# pakunihmarafak P AH0 K UH0 N IH0 HH M AH0 R AH0 F AH0 K
# pakunpaatvutih P AH0 K UH0 N P AA1 T V UH0 T IH0 HH
# pakunqahootih P AH0 K UH0 N T AH0 HH OW1 T IH0 HH
# pakupinivruuhtunva P AH0 K UH0 P IH0 N IH0 V R UW1 HH T UH0 N V AH0
# pakurih P AH0 K UH0 R IH0 HH
# pakuusrah P AH0 K UW1 SH R AH0 HH
# pakxuuyvi P AH0 K HH UW1 Y V IH0
# pamahqahup P AH0 M AH0 HH T AH0 HH UH0 P
# pamahqiit P AH0 M AH0 HH T IY1 T
# pamaq P AH0 M AH0 T
# pamaqninay P AH0 M AH0 T N IH0 N AH0 Y
# pamichishiih P AH0 M IH0 CH IH0 SH IY1 HH
# pamichnaat P AH0 M IH0 CH N AA1 T
# pamifyiiv P AH0 M IH0 F Y IY1 V
# pamihrooha P AH0 M IH0 HH R OW1 HH AH0
# pamiishxaar P AH0 M IY1 SH HH AA1 R
# pamikafih P AH0 M IH0 K AH0 F IH0 HH
# pamikrivraam P AH0 M IH0 K R IH0 V R AA1 M
# pamikunqaav P AH0 M IH0 K UH0 N T AA1 V
# pamikunsaanva P AH0 M IH0 K UH0 N SH AA1 N V AH0
# pamikunvu P AH0 M IH0 K UH0 N V UH0
# pamipaah P AH0 M IH0 P AA1 HH
# pamipoor P AH0 M IH0 P OW1 R
# pamipusihich P AH0 M IH0 P UH0 SH IH0 HH IH0 CH
# pamiputiruh P AH0 M IH0 P UH0 T IH0 R UH0 HH
# pamipuuvish P AH0 M IH0 P UW1 V IH0 SH
# pamiqaan P AH0 M IH0 T AA1 N
# pamiqakah P AH0 M IH0 T AH0 K AH0 HH
# pamiqapsiih P AH0 M IH0 T AH0 P SH IY1 HH
# pamiqaraaras P AH0 M IH0 T AH0 R AA1 R AH0 SH
# pamiqaramah P AH0 M IH0 T AH0 R AH0 M AH0 HH
# pamiqavaha P AH0 M IH0 T AH0 V AH0 HH AH0
# pamiqavan P AH0 M IH0 T AH0 V AH0 N
# pamiqavansa P AH0 M IH0 T AH0 V AH0 N SH AH0
# pamiqifunih P AH0 M IH0 T IH0 F UH0 N IH0 HH
# pamisikih P AH0 M IH0 SH IH0 K IH0 HH
# pamitaat P AH0 M IH0 T AA1 T
# pamithvuy P AH0 M IH0 TH V UH0 Y
# pamitiiv P AH0 M IH0 T IY1 V
# pamitipa P AH0 M IH0 T IH0 P AH0
# pamitunviiv P AH0 M IH0 T UH0 N V IY1 V
# pamivu P AH0 M IH0 V UH0
# pamixvaah P AH0 M IH0 HH V AA1 HH
# pamiyukukuh P AH0 M IH0 Y UH0 K UH0 K UH0 HH
# pamuchishiih P AH0 M UH0 CH IH0 SH IY1 HH
# pamuchivchakar P AH0 M UH0 CH IH0 V CH AH0 K AH0 R
# pamufithih P AH0 M UH0 F IH0 TH IH0 HH
# pamufithihak P AH0 M UH0 F IH0 TH IH0 HH AH0 K
# pamukeechikyav P AH0 M UH0 K EY1 CH IH0 K Y AH0 V
# pamukunquup P AH0 M UH0 K UH0 N T UW1 P
# pamupixuumvar P AH0 M UH0 P IH0 HH UW1 M V AH0 R
# pamupusihich P AH0 M UH0 P UH0 SH IH0 HH IH0 CH
# pamuqaan P AH0 M UH0 T AA1 N
# pamuqaasravar P AH0 M UH0 T AA1 SH R AH0 V AH0 R
# pamuqahup P AH0 M UH0 T AH0 HH UH0 P
# pamuqakah P AH0 M UH0 T AH0 K AH0 HH
# pamuqapsiih P AH0 M UH0 T AH0 P SH IY1 HH
# pamuqapsuun P AH0 M UH0 T AH0 P SH UW1 N
# pamuqapvuuy P AH0 M UH0 T AH0 P V UW1 Y
# pamuqapxaan P AH0 M UH0 T AH0 P HH AA1 N
# pamuqasimnaam P AH0 M UH0 T AH0 SH IH0 M N AA1 M
# pamuqasravara P AH0 M UH0 T AH0 SH R AH0 V AH0 R AH0
# pamuqatraax P AH0 M UH0 T AH0 T R AA1 HH
# pamuqifunih P AH0 M UH0 T IH0 F UH0 N IH0 HH
# pamuqishkiit P AH0 M UH0 T IH0 SH K IY1 T
# pamusara P AH0 M UH0 SH AH0 R AH0
# pamusmus P AH0 M UH0 SH M UH0 SH
# pamuyukukuh P AH0 M UH0 Y UH0 K UH0 K UH0 HH
# panaa P AH0 N AA1
# panakish P AH0 N AH0 K IH0 SH
# panamnihquuth P AH0 N AH0 M N IH0 HH T UW1 TH
# panamniik P AH0 N AH0 M N IY1 K
# panamnik P AH0 N AH0 M N IH0 K
# pananichishii P AH0 N AH0 N IH0 CH IH0 SH IY1
# pananichishiih P AH0 N AH0 N IH0 CH IH0 SH IY1 HH
# pananichuupha P AH0 N AH0 N IH0 CH UW1 P HH AH0
# pananifyiivshas P AH0 N AH0 N IH0 F Y IY1 V SH AH0 SH
# pananiishxaar P AH0 N AH0 N IY1 SH HH AA1 R
# pananikafih P AH0 N AH0 N IH0 K AH0 F IH0 HH
# pananikafihqasip P AH0 N AH0 N IH0 K AH0 F IH0 HH T AH0 SH IH0 P
# pananikiit P AH0 N AH0 N IH0 K IY1 T
# pananikrivraam P AH0 N AH0 N IH0 K R IH0 V R AA1 M
# pananikustaan P AH0 N AH0 N IH0 K UH0 SH T AA1 N
# pananikustaansa P AH0 N AH0 N IH0 K UH0 SH T AA1 N SH AH0
# pananinakish P AH0 N AH0 N IH0 N AH0 K IH0 SH
# pananipithxa P AH0 N AH0 N IH0 P IH0 TH HH AH0
# pananipusihich P AH0 N AH0 N IH0 P UH0 SH IH0 HH IH0 CH
# pananiputiruh P AH0 N AH0 N IH0 P UH0 T IH0 R UH0 HH
# pananipuuvish P AH0 N AH0 N IH0 P UW1 V IH0 SH
# pananiqahaknah P AH0 N AH0 N IH0 T AH0 HH AH0 K N AH0 HH
# pananiqahup P AH0 N AH0 N IH0 T AH0 HH UH0 P
# pananiqaka P AH0 N AH0 N IH0 T AH0 K AH0
# pananiqakah P AH0 N AH0 N IH0 T AH0 K AH0 HH
# pananiqapsiih P AH0 N AH0 N IH0 T AH0 P SH IY1 HH
# pananiqapxaan P AH0 N AH0 N IH0 T AH0 P HH AA1 N
# pananiqav P AH0 N AH0 N IH0 T AH0 V
# pananiqavan P AH0 N AH0 N IH0 T AH0 V AH0 N
# pananiqifunih P AH0 N AH0 N IH0 T IH0 F UH0 N IH0 HH
# pananiqishaha P AH0 N AH0 N IH0 T IH0 SH AH0 HH AH0
# pananisaanva P AH0 N AH0 N IH0 SH AA1 N V AH0
# pananitaat P AH0 N AH0 N IH0 T AA1 T
# pananithyur P AH0 N AH0 N IH0 TH Y UH0 R
# pananitipa P AH0 N AH0 N IH0 T IH0 P AH0
# pananitipah P AH0 N AH0 N IH0 T IH0 P AH0 HH
# pananivoonvanaach P AH0 N AH0 N IH0 V OW1 N V AH0 N AA1 CH
# pananivuh P AH0 N AH0 N IH0 V UH0 HH
# pananixvaah P AH0 N AH0 N IH0 HH V AA1 HH
# pananiyukuku P AH0 N AH0 N IH0 Y UH0 K UH0 K UH0
# pananiyukukuh P AH0 N AH0 N IH0 Y UH0 K UH0 K UH0 HH
# pananupiykirikir P AH0 N AH0 N UH0 P IH0 Y K IH0 R IH0 K IH0 R
# pananuqaah P AH0 N AH0 N UH0 T AA1 HH
# pananuqatraax P AH0 N AH0 N UH0 T AH0 T R AA1 HH
# pananusaanva P AH0 N AH0 N UH0 SH AA1 N V AH0
# pananuvuup P AH0 N AH0 N UH0 V UW1 P
# paneepmahoonkoonatihara P AH0 N EY1 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH AH0 R AH0
# paniheeratih P AH0 N IH0 HH EY1 R AH0 T IH0 HH
# panikpuuhtih P AH0 N IH0 K P UW1 HH T IH0 HH
# panikrii P AH0 N IH0 K R IY1
# panikupapuukeevish P AH0 N IH0 K UH0 P AH0 P UW1 K EY1 V IH0 SH
# panikupheesh P AH0 N IH0 K UH0 P HH EY1 SH
# paninikeechikyav P AH0 N IH0 N IH0 K EY1 CH IH0 K Y AH0 V
# paninipakurih P AH0 N IH0 N IH0 P AH0 K UH0 R IH0 HH
# paninipusihich P AH0 N IH0 N IH0 P UH0 SH IH0 HH IH0 CH
# paninivuh P AH0 N IH0 N IH0 V UH0 HH
# panipakuriihvutih P AH0 N IH0 P AH0 K UH0 R IY1 HH V UH0 T IH0 HH
# panipihniichhaak P AH0 N IH0 P IH0 HH N IY1 CH HH AA1 K
# paniqahootih P AH0 N IH0 T AH0 HH OW1 T IH0 HH
# paniqeethkaanvahaak P AH0 N IH0 T EY1 TH K AA1 N V AH0 HH AA1 K
# panishxaaytih P AH0 N IH0 SH HH AA1 Y T IH0 HH
# panithaaniv P AH0 N IH0 TH AA1 N IH0 V
# panithafiiptih P AH0 N IH0 TH AH0 F IY1 P T IH0 HH
# panivaarameesh P AH0 N IH0 V AA1 R AH0 M EY1 SH
# paniviiktih P AH0 N IH0 V IY1 K T IH0 HH
# paniyuupheen P AH0 N IH0 Y UW1 P HH EY1 N
# panuchuphunishkoonaatih P AH0 N UH0 CH UH0 P HH UH0 N IH0 SH K OW1 N AA1 T IH0 HH
# panukviitihat P AH0 N UH0 K V IY1 T IH0 HH AH0 T
# panunuquhthaam P AH0 N UH0 N UH0 T UH0 HH TH AA1 M
# panuqaveesh P AH0 N UH0 T AH0 V EY1 SH
# panuqiishtih P AH0 N UH0 T IY1 SH T IH0 HH
# panuviitihaak P AH0 N UH0 V IY1 T IH0 HH AA1 K
# panuvyiihmahaak P AH0 N UH0 V Y IY1 HH M AH0 HH AA1 K
# paorleans P AH0 OW0 R L EH0 AH0 N SH
# papaah P AH0 P AA1 HH
# papakiihar P AH0 P AH0 K IY1 HH AH0 R
# papay P AH0 P AH0 Y
# papihneefich P AH0 P IH0 HH N EY1 F IH0 CH
# papimnaanih P AH0 P IH0 M N AA1 N IH0 HH
# papoos P AH0 P OW1 SH
# paporch P AH0 P OW0 R CH
# papufichqiish P AH0 P UH0 F IH0 CH T IY1 SH
# papunaquusurutih P AH0 P UH0 N AH0 T UW1 SH UH0 R UH0 T IH0 HH
# papusihich P AH0 P UH0 SH IH0 HH IH0 CH
# papusihichqavah P AH0 P UH0 SH IH0 HH IH0 CH T AH0 V AH0 HH
# paputiruh P AH0 P UH0 T IH0 R UH0 HH
# papuufich P AH0 P UW1 F IH0 CH
# papuuvish P AH0 P UW1 V IH0 SH
# paqa1hup P AH0 T AH0 HH UH0 P
# paqa1sak P AH0 T AH0 SH AH0 K
# paqa1thik P AH0 T AH0 TH IH0 K
# paqaah P AH0 T AA1 HH
# paqaama P AH0 T AA1 M AH0
# paqaan P AH0 T AA1 N
# paqaanxus P AH0 T AA1 N HH UH0 SH
# paqaapunmuti P AH0 T AA1 P UH0 N M UH0 T IH0
# paqaas P AH0 T AA1 SH
# paqachkuun P AH0 T AH0 CH K UW1 N
# paqachnaat P AH0 T AH0 CH N AA1 T
# paqachviiv P AH0 T AH0 CH V IY1 V
# paqahaknak P AH0 T AH0 HH AH0 K N AH0 K
# paqahup P AH0 T AH0 HH UH0 P
# paqakraa P AH0 T AH0 K R AA1
# paqakraah P AH0 T AH0 K R AA1 HH
# paqakvaat P AH0 T AH0 K V AA1 T
# paqakviish P AH0 T AH0 K V IY1 SH
# paqamkir P AH0 T AH0 M K IH0 R
# paqamkirak P AH0 T AH0 M K IH0 R AH0 K
# paqapsuun P AH0 T AH0 P SH UW1 N
# paqapus P AH0 T AH0 P UH0 SH
# paqapxaan P AH0 T AH0 P HH AA1 N
# paqapxantinihich P AH0 T AH0 P HH AH0 N T IH0 N IH0 HH IH0 CH
# paqaq P AH0 T AH0 T
# paqaraar P AH0 T AH0 R AA1 R
# paqaraaras P AH0 T AH0 R AA1 R AH0 SH
# paqararahih P AH0 T AH0 R AH0 R AH0 HH IH0 HH
# paqas P AH0 T AH0 SH
# paqasiktavaan P AH0 T AH0 SH IH0 K T AH0 V AA1 N
# paqasiktavaansa P AH0 T AH0 SH IH0 K T AH0 V AA1 N SH AH0
# paqasip P AH0 T AH0 SH IH0 P
# paqatimnam P AH0 T AH0 T IH0 M N AH0 M
# paqav P AH0 T AH0 V
# paqavaha P AH0 T AH0 V AH0 HH AH0
# paqavansa P AH0 T AH0 V AH0 N SH AH0
# paqavansas P AH0 T AH0 V AH0 N SH AH0 SH
# paqavansaxiich P AH0 T AH0 V AH0 N SH AH0 HH IY1 CH
# paqaxiich P AH0 T AH0 HH IY1 CH
# paqaxiichas P AH0 T AH0 HH IY1 CH AH0 SH
# paqaxiitichas P AH0 T AH0 HH IY1 T IH0 CH AH0 SH
# paqeeth P AH0 T EY1 TH
# paqihukar P AH0 T IH0 HH UH0 K AH0 R
# paqiihyan P AH0 T IY1 HH Y AH0 N
# paqiirish P AH0 T IY1 R IH0 SH
# paqikrivkir P AH0 T IH0 K R IH0 V K IH0 R
# paqikrivraam P AH0 T IH0 K R IH0 V R AA1 M
# paqikrivramqaaxkunish P AH0 T IH0 K R IH0 V R AH0 M T AA1 HH K UH0 N IH0 SH
# paqikxaram P AH0 T IH0 K HH AH0 R AH0 M
# paqikxaramkunish P AH0 T IH0 K HH AH0 R AH0 M K UH0 N IH0 SH
# paqikxurikar P AH0 T IH0 K HH UH0 R IH0 K AH0 R
# paqimpaah P AH0 T IH0 M P AA1 HH
# paqip P AH0 T IH0 P
# paqipa P AH0 T IH0 P AH0
# paqipaha P AH0 T IH0 P AH0 HH AH0
# paqipahak P AH0 T IH0 P AH0 HH AH0 K
# paqipit P AH0 T IH0 P IH0 T
# paqipita P AH0 T IH0 P IH0 T AH0
# paqishah P AH0 T IH0 SH AH0 HH
# paqishaha P AH0 T IH0 SH AH0 HH AH0
# paqishahak P AH0 T IH0 SH AH0 HH AH0 K
# paqishimfir P AH0 T IH0 SH IH0 M F IH0 R
# paqishkeesh P AH0 T IH0 SH K EY1 SH
# paqsara P AH0 T SH AH0 R AH0
# paqukriivtih P AH0 T UH0 K R IY1 V T IH0 HH
# paqunuhxiitich P AH0 T UH0 N UH0 HH HH IY1 T IH0 CH
# paquuxkunish P AH0 T UW1 HH K UH0 N IH0 SH
# paramva P AH0 R AH0 M V AH0
# parap P AH0 R AH0 P
# party P AH0 R T Y
# pasaan P AH0 SH AA1 N
# pasahqa1hup P AH0 SH AH0 HH T AH0 HH UH0 P
# pasahqahup P AH0 SH AH0 HH T AH0 HH UH0 P
# pasara P AH0 SH AH0 R AH0
# pasasip P AH0 SH AH0 SH IH0 P
# pasikih P AH0 SH IH0 K IH0 HH
# pata P AH0 T AH0
# pataay P AH0 T AA1 Y
# patakaakaa P AH0 T AH0 K AA1 K AA1
# patakaakaatunveechas P AH0 T AH0 K AA1 K AA1 T UH0 N V EY1 CH AH0 SH
# pataripaan P AH0 T AH0 R IH0 P AA1 N
# patas P AH0 T AH0 SH
# patasakaam P AH0 T AH0 SH AH0 K AA1 M
# path P AH0 TH
# pathufkirik P AH0 TH UH0 F K IH0 R IH0 K
# pathyur P AH0 TH Y UH0 R
# pathyuru P AH0 TH Y UH0 R UH0
# patoo P AH0 T OW1
# patuchixaanahaak P AH0 T UH0 CH IH0 HH AA1 N AH0 HH AA1 K
# patupufaat P AH0 T UH0 P UH0 F AA1 T
# patusupaaha P AH0 T UH0 SH UH0 P AA1 HH AH0
# pavirusur P AH0 V IH0 R UH0 SH UH0 R
# pavirusura P AH0 V IH0 R UH0 SH UH0 R AH0
# pawashingmachine P AH0 W AH0 SH IH0 N G M AH0 CH IH0 N EH0
# paweasel P AH0 W EH0 AH0 SH EH0 L
# paxa1nkiit P AH0 HH AH0 N K IY1 T
# paxanchiifich P AH0 HH AH0 N CH IY1 F IH0 CH
# paxankiit P AH0 HH AH0 N K IY1 T
# paxanthiip P AH0 HH AH0 N TH IY1 P
# paxiichas P AH0 HH IY1 CH AH0 SH
# paxuntapan P AH0 HH UH0 N T AH0 P AH0 N
# paxuntapanheesh P AH0 HH UH0 N T AH0 P AH0 N HH EY1 SH
# paxut P AH0 HH UH0 T
# paxuun P AH0 HH UW1 N
# paxvaah P AH0 HH V AA1 HH
# pay P AH0 Y
# payaasqara P AH0 Y AA1 SH T AH0 R AH0
# payav P AH0 Y AH0 V
# payeem P AH0 Y EY1 M
# payeenipaxvuhichas P AH0 Y EY1 N IH0 P AH0 HH V UH0 HH IH0 CH AH0 SH
# payitha P AH0 Y IH0 TH AH0
# paykich P AH0 Y K IH0 CH
# paykuuk P AH0 Y K UW1 K
# payook P AH0 Y OW1 K
# payqook P AH0 Y T OW1 K
# payufish P AH0 Y UH0 F IH0 SH
# payupsitanach P AH0 Y UH0 P SH IH0 T AH0 N AH0 CH
# payupsitanich P AH0 Y UH0 P SH IH0 T AH0 N IH0 CH
# payuraschishiih P AH0 Y UH0 R AH0 SH CH IH0 SH IY1 HH
# peekrii P EY1 K R IY1
# peekrivkir P EY1 K R IH0 V K IH0 R
# peekrivraam P EY1 K R IH0 V R AA1 M
# peekrivraamak P EY1 K R IH0 V R AA1 M AH0 K
# peekrivramqaaxkunish P EY1 K R IH0 V R AH0 M T AA1 HH K UH0 N IH0 SH
# peekrupkaanvar P EY1 K R UH0 P K AA1 N V AH0 R
# peekukak P EY1 K UH0 K AH0 K
# peekvareesh P EY1 K V AH0 R EY1 SH
# peekxareeyav P EY1 K HH AH0 R EY1 Y AH0 V
# peekyaveesh P EY1 K Y AH0 V EY1 SH
# peemnisheesh P EY1 M N IH0 SH EY1 SH
# peempaah P EY1 M P AA1 HH
# peemuusti P EY1 M UW1 SH T IH0
# peemuustih P EY1 M UW1 SH T IH0 HH
# peen P EY1 N
# peepihniichha P EY1 P IH0 HH N IY1 CH HH AH0
# peepithvaram P EY1 P IH0 TH V AH0 R AH0 M
# peepitih P EY1 P IH0 T IH0 HH
# peeqaamtih P EY1 T AA1 M T IH0 HH
# peeqahooti P EY1 T AH0 HH OW1 T IH0
# peeqavaheen P EY1 T AH0 V AH0 HH EY1 N
# peeshkaaktih P EY1 SH K AA1 K T IH0 HH
# peeshkeesh P EY1 SH K EY1 SH
# peeshnanichqishiip P EY1 SH N AH0 N IH0 CH T IH0 SH IY1 P
# peethyur P EY1 TH Y UH0 R
# peevishtaantih P EY1 V IH0 SH T AA1 N T IH0 HH
# peevoonfuruk P EY1 V OW1 N F UH0 R UH0 K
# peexapkooti P EY1 HH AH0 P K OW1 T IH0
# peexraratih P EY1 HH R AH0 R AH0 T IH0 HH
# peter P EH0 T EH0 R
# phil P HH IH0 L
# pihneefich P IH0 HH N EY1 F IH0 CH
# piimich P IY1 M IH0 CH
# piip P IY1 P
# piipi P IY1 P IH0
# pikyav P IH0 K Y AH0 V
# pimkuutihara P IH0 M K UW1 T IH0 HH AH0 R AH0
# pimnaanih P IH0 M N AA1 N IH0 HH
# pimustihvaanar P IH0 M UH0 SH T IH0 HH V AA1 N AH0 R
# piqeep P IH0 T EY1 P
# pirish P IH0 R IH0 SH
# pishiip P IH0 SH IY1 P
# pishnakarishuk P IH0 SH N AH0 K AH0 R IH0 SH UH0 K
# pishpoonivoon P IH0 SH P OW1 N IH0 V OW1 N
# pithxahi P IH0 TH HH AH0 HH IH0
# pithyaan P IH0 TH Y AA1 N
# pmahoonkoon P M AH0 HH OW1 N K OW1 N
# ...
# puneekfuuytihara P UH0 N EY1 K F UW1 Y T IH0 HH AH0 R AH0
# puneekviihitihara P UH0 N EY1 K V IY1 HH IH0 T IH0 HH AH0 R AH0
# puneemshakaantihara P UH0 N EY1 M SH AH0 K AA1 N T IH0 HH AH0 R AH0
# puneexraratihara P UH0 N EY1 HH R AH0 R AH0 T IH0 HH AH0 R AH0
# puneexratihara P UH0 N EY1 HH R AH0 T IH0 HH AH0 R AH0
# punupareeshara P UH0 N UH0 P AH0 R EY1 SH AH0 R AH0
# punupitaptihara P UH0 N UH0 P IH0 T AH0 P T IH0 HH AH0 R AH0
# punuqafishrihara P UH0 N UH0 T AH0 F IH0 SH R IH0 HH AH0 R AH0
# punuthitiimtihara P UH0 N UH0 TH IH0 T IY1 M T IH0 HH AH0 R AH0
# pupimkuuhtihara P UH0 P IH0 M K UW1 HH T IH0 HH AH0 R AH0
# pupimkuutihara P UH0 P IH0 M K UW1 T IH0 HH AH0 R AH0
# pupitihara P UH0 P IH0 T IH0 HH AH0 R AH0
# puptaxatiihtihara P UH0 P T AH0 HH AH0 T IY1 HH T IH0 HH AH0 R AH0
# puqaamtihara P UH0 T AA1 M T IH0 HH AH0 R AH0
# puqaapunmuti P UH0 T AA1 P UH0 N M UH0 T IH0
# puqaapunmutihara P UH0 T AA1 P UH0 N M UH0 T IH0 HH AH0 R AH0
# puqahup P UH0 T AH0 HH UH0 P
# puqathik P UH0 T AH0 TH IH0 K
# puquum P UH0 T UW1 M
# puraan P UH0 R AA1 N
# purafaat P UH0 R AH0 F AA1 T
# purafataak P UH0 R AH0 F AH0 T AA1 K
# purafatak P UH0 R AH0 F AH0 T AH0 K
# purih P UH0 R IH0 HH
# pusihich P UH0 SH IH0 HH IH0 CH
# pusihichqavah P UH0 SH IH0 HH IH0 CH T AH0 V AH0 HH
# puta P UH0 T AH0
# putaay P UH0 T AA1 Y
# putiruh P UH0 T IH0 R UH0 HH
# puufich P UW1 F IH0 CH
# puuhara P UW1 HH AH0 R AH0
# puun P UW1 N
# puuvish P UW1 V IH0 SH
# puvaa P UH0 V AA1
# puxay P UH0 HH AH0 Y
# puxich P UH0 HH IH0 CH
# puxraratih P UH0 HH R AH0 R AH0 T IH0 HH
# puya P UH0 Y AH0
# puyaamachhara P UH0 Y AA1 M AH0 CH HH AH0 R AH0
# puyaif P UH0 Y AH0 IH0 F
# puyav P UH0 Y AH0 V
# puyava P UH0 Y AH0 V AH0
# puyavhara P UH0 Y AH0 V HH AH0 R AH0
# pvaaram P V AA1 R AH0 M
# pvoonfuruk P V OW1 N F UH0 R UH0 K
# qas T AH0 SH
# qikxipma T IH0 K HH IH0 P M AH0
# qkari T K AH0 R IH0
# ramona R AH0 M OW0 N AH0
# saanfuruki SH AA1 N F UH0 R UH0 K IH0
# sahishyuuxach SH AH0 HH IH0 SH Y UW1 HH AH0 CH
# sahqahup SH AH0 HH T AH0 HH UH0 P
# sally SH AH0 L L Y
# sara SH AH0 R AH0
# saraxutnahich SH AH0 R AH0 HH UH0 T N AH0 HH IH0 CH
# saruk SH AH0 R UH0 K
# schur SH CH UH0 R
# skaaksur SH K AA1 K SH UH0 R
# skakunih SH K AH0 K UH0 N IH0 HH
# skakuraa SH K AH0 K UH0 R AA1
# snur SH N UH0 R
# soap SH OW0 AH0 P
# spas SH P AH0 SH
# spat SH P AH0 T
# supaah SH UH0 P AA1 HH
# suq SH UH0 T
# surukam SH UH0 R UH0 K AH0 M
# suva SH UH0 V AH0
# suvanik SH UH0 V AH0 N IH0 K
# ta T AH0
# taahkunish T AA1 HH K UH0 N IH0 SH
# taak T AA1 K
# taay T AA1 Y
# takanukreeni T AH0 K AH0 N UH0 K R EY1 N IH0
# takav T AH0 K AH0 V
# tama T AH0 M AH0
# tamtipshi1ina T AH0 M T IH0 P SH IY1 N AH0
# tanukyaanar T AH0 N UH0 K Y AA1 N AH0 R
# tapas T AH0 P AH0 SH
# taqitam T AH0 T IH0 T AH0 M
# tas T AH0 SH
# tee T EY1
# teeheech T EY1 HH EY1 CH
# teek T EY1 K
# teekshah T EY1 K SH AH0 HH
# teekyaatih T EY1 K Y AA1 T IH0 HH
# teekyav T EY1 K Y AH0 V
# teep T EY1 P
# teepsheek T EY1 P SH EY1 K
# teepshinvarihva T EY1 P SH IH0 N V AH0 R IH0 HH V AH0
# teepshitaanih T EY1 P SH IH0 T AA1 N IH0 HH
# teeqaathva T EY1 T AA1 TH V AH0
# teexra T EY1 HH R AH0
# teexuriha T EY1 HH UH0 R IH0 HH AH0
# teexviipha T EY1 HH V IY1 P HH AH0
# teexviphuunish T EY1 HH V IH0 P HH UW1 N IH0 SH
# thaankurih TH AA1 N K UH0 R IH0 HH
# tharishrih TH AH0 R IH0 SH R IH0 HH
# thiishrih TH IY1 SH R IH0 HH
# thufkirik TH UH0 F K IH0 R IH0 K
# tii T IY1
# tikariha T IH0 K AH0 R IH0 HH AH0
# tikunpikni T IH0 K UH0 N P IH0 K N IH0
# tipipshiinvarihva T IH0 P IH0 P SH IY1 N V AH0 R IH0 HH V AH0
# tipishriivpa T IH0 P IH0 SH R IY1 V P AH0
# tipivaxrah T IH0 P IH0 V AH0 HH R AH0 HH
# tiqaapunma T IH0 T AA1 P UH0 N M AH0
# tiqaramsiip T IH0 T AH0 R AH0 M SH IY1 P
# tiqaramsiiprin T IH0 T AH0 R AH0 M SH IY1 P R IH0 N
# tiqaramsiipriv T IH0 T AH0 R AH0 M SH IY1 P R IH0 V
# tiqav T IH0 T AH0 V
# tiqif T IH0 T IH0 F
# tiqiin T IH0 T IY1 N
# tiqiipma T IH0 T IY1 P M AH0
# tiqitapti T IH0 T IH0 T AH0 P T IH0
# tishanihquuth T IH0 SH AH0 N IH0 HH T UW1 TH
# tithafip T IH0 TH AH0 F IH0 P
# tithitiv T IH0 TH IH0 T IH0 V
# titxaarihva T IH0 T HH AA1 R IH0 HH V AH0
# tivaaram T IH0 V AA1 R AH0 M
# tivooruraa T IH0 V OW1 R UH0 R AA1
# to1omchax T OW1 M CH AH0 HH
# to1omchaxayaacha T OW1 M CH AH0 HH AH0 Y AA1 CH AH0
# too T OW1
# tookfuk T OW1 K F UH0 K
# tookrii T OW1 K R IY1
# tookxipshur T OW1 K HH IH0 P SH UH0 R
# tookyav T OW1 K Y AH0 V
# toomchax T OW1 M CH AH0 HH
# toopiimshur T OW1 P IY1 M SH UH0 R
# toopiip T OW1 P IY1 P
# tooyveeshriheen T OW1 Y V EY1 SH R IH0 HH EY1 N
# traa T R AA1
# tufurathfip T UH0 F UH0 R AH0 TH F IH0 P
# tukeevniikichha T UH0 K EY1 V N IY1 K IH0 CH HH AH0
# tukuniihka T UH0 K UH0 N IY1 HH K AH0
# tukviripma T UH0 K V IH0 R IH0 P M AH0
# tumah T UH0 M AH0 HH
# tupaathka T UH0 P AA1 TH K AH0
# tupaathunih T UH0 P AA1 TH UH0 N IH0 HH
# tupaathuraa T UH0 P AA1 TH UH0 R AA1
# tupathrih T UH0 P AH0 TH R IH0 HH
# tupihniichha T UH0 P IH0 HH N IY1 CH HH AH0
# tupikniivratih T UH0 P IH0 K N IY1 V R AH0 T IH0 HH
# tupishyaavpa T UH0 P IH0 SH Y AA1 V P AH0
# tupithxah T UH0 P IH0 TH HH AH0 HH
# tupivaxrah T UH0 P IH0 V AH0 HH R AH0 HH
# tupuxichkaanva T UH0 P UH0 HH IH0 CH K AA1 N V AH0
# tuqaapunma T UH0 T AA1 P UH0 N M AH0
# tuqahoo T UH0 T AH0 HH OW1
# tuqaramsiip T UH0 T AH0 R AH0 M SH IY1 P
# tuqaramsiiprivtih T UH0 T AH0 R AH0 M SH IY1 P R IH0 V T IH0 HH
# tuqarihfak T UH0 T AH0 R IH0 HH F AH0 K
# tuqarihishrih T UH0 T AH0 R IH0 HH IH0 SH R IH0 HH
# tuqav T UH0 T AH0 V
# tuqavat T UH0 T AH0 V AH0 T
# tuqaxaska T UH0 T AH0 HH AH0 SH K AH0
# tuqay T UH0 T AH0 Y
# tuqeeh T UH0 T EY1 HH
# tuqichunva T UH0 T IH0 CH UH0 N V AH0
# tuqif T UH0 T IH0 F
# tuqih T UH0 T IH0 HH
# tuqiin T UH0 T IY1 N
# tuqiinish T UH0 T IY1 N IH0 SH
# tuqiinka T UH0 T IY1 N K AH0
# tuqiinkayaachha T UH0 T IY1 N K AH0 Y AA1 CH HH AH0
# tuqiinva T UH0 T IY1 N V AH0
# tuqiinvunaati T UH0 T IY1 N V UH0 N AA1 T IH0
# tuqipak T UH0 T IH0 P AH0 K
# tuqishriivha T UH0 T IH0 SH R IY1 V HH AH0
# tuquh T UH0 T UH0 HH
# tuquum T UH0 T UW1 M
# tuskak T UH0 SH K AH0 K
# tusupaaha T UH0 SH UH0 P AA1 HH AH0
# tutatuyish T UH0 T AH0 T UH0 Y IH0 SH
# tutatuyishrih T UH0 T AH0 T UH0 Y IH0 SH R IH0 HH
# tuthaaniv T UH0 TH AA1 N IH0 V
# tuthitiv T UH0 TH IH0 T IH0 V
# tuvaaram T UH0 V AA1 R AH0 M
# tuvaasip T UH0 V AA1 SH IH0 P
# tuvasip T UH0 V AH0 SH IH0 P
# tuvaxrah T UH0 V AH0 HH R AH0 HH
# tuvoonfuruk T UH0 V OW1 N F UH0 R UH0 K
# tuvooruraa T UH0 V OW1 R UH0 R AA1
# tuvooruvrathaheen T UH0 V OW1 R UH0 V R AH0 TH AH0 HH EY1 N
# tuvupaksur T UH0 V UH0 P AH0 K SH UH0 R
# tuvupaksuroo T UH0 V UH0 P AH0 K SH UH0 R OW1
# tuxaychakish T UH0 HH AH0 Y CH AH0 K IH0 SH
# tuxus T UH0 HH UH0 SH
# tuyikiha T UH0 Y IH0 K IH0 HH AH0
# tuyshipqipan T UH0 Y SH IH0 P T IH0 P AH0 N
# tuyunyuunha T UH0 Y UH0 N Y UW1 N HH AH0
# tuyvukquuth T UH0 Y V UH0 K T UW1 TH
# uchiishhiti UH0 CH IY1 SH HH IH0 T IH0
# uchish UH0 CH IH0 SH
# uchuphunishkooti UH0 CH UH0 P HH UH0 N IH0 SH K OW1 T IH0
# uchuuphitih UH0 CH UW1 P HH IH0 T IH0 HH
# uhruuvtih UH0 HH R UW1 V T IH0 HH
# uhyanavaraar UH0 HH Y AH0 N AH0 V AH0 R AA1 R
# uhyarih UH0 HH Y AH0 R IH0 HH
# uhyariheesh UH0 HH Y AH0 R IH0 HH EY1 SH
# uhyiivtih UH0 HH Y IY1 V T IH0 HH
# ukfukuraa UH0 K F UH0 K UH0 R AA1
# ukfukuvraa UH0 K F UH0 K UH0 V R AA1
# ukfuukraaheen UH0 K F UW1 K R AA1 HH EY1 N
# ukfuuyshur UH0 K F UW1 Y SH UH0 R
# ukfuyfuuytih UH0 K F UH0 Y F UW1 Y T IH0 HH
# ukitnaaktih UH0 K IH0 T N AA1 K T IH0 HH
# uknamxanahich UH0 K N AH0 M HH AH0 N AH0 HH IH0 CH
# ukpuuhtih UH0 K P UW1 HH T IH0 HH
# ukreenik UH0 K R EY1 N IH0 K
# ukreet UH0 K R EY1 T
# ukrii UH0 K R IY1
# ukriivtih UH0 K R IY1 V T IH0 HH
# ukriv UH0 K R IH0 V
# ukrivruhish UH0 K R IH0 V R UH0 HH IH0 SH
# ukrivruhunih UH0 K R IH0 V R UH0 HH UH0 N IH0 HH
# ukrivruuhsipreeheen UH0 K R IH0 V R UW1 HH SH IH0 P R EY1 HH EY1 N
# uksaahtih UH0 K SH AA1 HH T IH0 HH
# uktinvunaatih UH0 K T IH0 N V UH0 N AA1 T IH0 HH
# ukuniihka UH0 K UH0 N IY1 HH K AH0
# ukuniihkat UH0 K UH0 N IY1 HH K AH0 T
# ukuniihkeesh UH0 K UH0 N IY1 HH K EY1 SH
# ukupaveenah UH0 K UH0 P AH0 V EY1 N AH0 HH
# ukuphaanik UH0 K UH0 P HH AA1 N IH0 K
# ukuuntakoo UH0 K UW1 N T AH0 K OW1
# ukviip UH0 K V IY1 P
# ukviithitih UH0 K V IY1 TH IH0 T IH0 HH
# ukviripship UH0 K V IH0 R IH0 P SH IH0 P
# ukxiipship UH0 K HH IY1 P SH IH0 P
# ukxiiptih UH0 K HH IY1 P T IH0 HH
# ukxipithunatipatoo UH0 K HH IH0 P IH0 TH UH0 N AH0 T IH0 P AH0 T OW1
# ukyaaheen UH0 K Y AA1 HH EY1 N
# ukyaanik UH0 K Y AA1 N IH0 K
# ukyaat UH0 K Y AA1 T
# ukyaati UH0 K Y AA1 T IH0
# ukyamiichvutih UH0 K Y AH0 M IY1 CH V UH0 T IH0 HH
# ukyav UH0 K Y AH0 V
# ukyivishrih UH0 K Y IH0 V IH0 SH R IH0 HH
# ukyivivrath UH0 K Y IH0 V IH0 V R AH0 TH
# ukyivunih UH0 K Y IH0 V UH0 N IH0 HH
# ukyutunihat UH0 K Y UH0 T UH0 N IH0 HH AH0 T
# um UH0 M
# uma UH0 M AH0
# umahtih UH0 M AH0 HH T IH0 HH
# umchaxeesh UH0 M CH AH0 HH EY1 SH
# umkuufha UH0 M K UW1 F HH AH0
# umniishti UH0 M N IY1 SH T IH0
# umniishtiheesh UH0 M N IY1 SH T IH0 HH EY1 SH
# umpaan UH0 M P AA1 N
# umshiipvunaa UH0 M SH IY1 P V UH0 N AA1
# umusahiti UH0 M UH0 SH AH0 HH IH0 T IH0
# umusahitih UH0 M UH0 SH AH0 HH IH0 T IH0 HH
# umuusti UH0 M UW1 SH T IH0
# umuustih UH0 M UW1 SH T IH0 HH
# umuustihinaa UH0 M UW1 SH T IH0 HH IH0 N AA1
# upaanvathvunaa UH0 P AA1 N V AH0 TH V UH0 N AA1
# upaatvutih UH0 P AA1 T V UH0 T IH0 HH
# upakuriihva UH0 P AH0 K UH0 R IY1 HH V AH0
# upakuriihvaheen UH0 P AH0 K UH0 R IY1 HH V AH0 HH EY1 N
# upakuriihvutih UH0 P AH0 K UH0 R IY1 HH V UH0 T IH0 HH
# upanaknaakti UH0 P AH0 N AH0 K N AA1 K T IH0
# upatapata UH0 P AH0 T AH0 P AH0 T AH0
# upathrihat UH0 P AH0 TH R IH0 HH AH0 T
# upathriheesh UH0 P AH0 TH R IH0 HH EY1 SH
# upathriihti UH0 P AH0 TH R IY1 HH T IH0
# upathriihtih UH0 P AH0 TH R IY1 HH T IH0 HH
# upatumka UH0 P AH0 T UH0 M K AH0
# upeenvunaa UH0 P EY1 N V UH0 N AA1
# upeer UH0 P EY1 R
# upeereesh UH0 P EY1 R EY1 SH
# upeesh UH0 P EY1 SH
# upeetharanik UH0 P EY1 TH AH0 R AH0 N IH0 K
# upi1mkuutih UH0 P IH0 M K UW1 T IH0 HH
# upiheer UH0 P IH0 HH EY1 R
# upiip UH0 P IY1 P
# upiip: UH0 P IY1 P
# upiivkirih UH0 P IY1 V K IH0 R IH0 HH
# upikriish UH0 P IH0 K R IY1 SH
# upikvah UH0 P IH0 K V AH0 HH
# upikviripvarak UH0 P IH0 K V IH0 R IH0 P V AH0 R AH0 K
# upikyafipayaachha UH0 P IH0 K Y AH0 F IH0 P AH0 Y AA1 CH HH AH0
# upimkuuhti UH0 P IH0 M K UW1 HH T IH0
# upimkuuhtivaa UH0 P IH0 M K UW1 HH T IH0 V AA1
# upishkaakrupuk UH0 P IH0 SH K AA1 K R UH0 P UH0 K
# upishkaaksip UH0 P IH0 SH K AA1 K SH IH0 P
# upithxah UH0 P IH0 TH HH AH0 HH
# upitih UH0 P IH0 T IH0 HH
# upivrihishtih UH0 P IH0 V R IH0 HH IH0 SH T IH0 HH
# upiytuykaanva UH0 P IH0 Y T UH0 Y K AA1 N V AH0
# upiytuykaanvaheen UH0 P IH0 Y T UH0 Y K AA1 N V AH0 HH EY1 N
# upiyuunvar UH0 P IH0 Y UW1 N V AH0 R
# upmahoonkoonatih UH0 P M AH0 HH OW1 N K OW1 N AH0 T IH0 HH
# upsaravriiktih UH0 P SH AH0 R AH0 V R IY1 K T IH0 HH
# upsheek UH0 P SH EY1 K
# upthivkeeheen UH0 P TH IH0 V K EY1 HH EY1 N
# upvaaram UH0 P V AA1 R AH0 M
# upvoonfuruk UH0 P V OW1 N F UH0 R UH0 K
# upvoonsip UH0 P V OW1 N SH IH0 P
# uqaamtih UH0 T AA1 M T IH0 HH
# uqaapunmahaak UH0 T AA1 P UH0 N M AH0 HH AA1 K
# uqaasishrihat UH0 T AA1 SH IH0 SH R IH0 HH AH0 T
# uqaasishriheen UH0 T AA1 SH IH0 SH R IH0 HH EY1 N
# uqaharamuraatih UH0 T AH0 HH AH0 R AH0 M UH0 R AA1 T IH0 HH
# uqahinaatih UH0 T AH0 HH IH0 N AA1 T IH0 HH
# uqahirim UH0 T AH0 HH IH0 R IH0 M
# uqahoo UH0 T AH0 HH OW1
# uqahooti UH0 T AH0 HH OW1 T IH0
# uqakunvuti UH0 T AH0 K UH0 N V UH0 T IH0
# uqaramsiiprivti UH0 T AH0 R AH0 M SH IY1 P R IH0 V T IH0
# uqaramsiiprivtih UH0 T AH0 R AH0 M SH IY1 P R IH0 V T IH0 HH
# uqarihish UH0 T AH0 R IH0 HH IH0 SH
# uqarihishriheen: UH0 T AH0 R IH0 HH IH0 SH R IH0 HH EY1 N
# uqarihrupuk UH0 T AH0 R IH0 HH R UH0 P UH0 K
# uqarihshipriv UH0 T AH0 R IH0 HH SH IH0 P R IH0 V
# uqavaheen UH0 T AH0 V AH0 HH EY1 N
# uqavat UH0 T AH0 V AH0 T
# uqaveesh UH0 T AH0 V EY1 SH
# uqeeh UH0 T EY1 HH
# uqeehvunaatih UH0 T EY1 HH V UH0 N AA1 T IH0 HH
# uqeethat UH0 T EY1 TH AH0 T
# uqeethkaanvaheen UH0 T EY1 TH K AA1 N V AH0 HH EY1 N
# uqichunvutih UH0 T IH0 CH UH0 N V UH0 T IH0 HH
# uqiihya UH0 T IY1 HH Y AH0
# uqiipkurih UH0 T IY1 P K UH0 R IH0 HH
# uqipahooheen UH0 T IH0 P AH0 HH OW1 HH EY1 N
# uqqichunvutih UH0 T T IH0 CH UH0 N V UH0 T IH0 HH
# uquuhtih UH0 T UW1 HH T IH0 HH
# uquum UH0 T UW1 M
# uquumaheen UH0 T UW1 M AH0 HH EY1 N
# usaanfuruki UH0 SH AA1 N F UH0 R UH0 K IH0
# usnurat UH0 SH N UH0 R AH0 T
# usuviish UH0 SH UH0 V IY1 SH
# usxaareesh UH0 SH HH AA1 R EY1 SH
# utakararih UH0 T AH0 K AH0 R AH0 R IH0 HH
# utakirtih UH0 T AH0 K IH0 R T IH0 HH
# utapkuuputih UH0 T AH0 P K UW1 P UH0 T IH0 HH
# utatuyishrihti UH0 T AH0 T UH0 Y IH0 SH R IH0 HH T IH0
# uthaaniv UH0 TH AA1 N IH0 V
# uthaantakoo UH0 TH AA1 N T AH0 K OW1
# uthiinatih UH0 TH IY1 N AH0 T IH0 HH
# uthitiv UH0 TH IH0 T IH0 V
# uthiv UH0 TH IH0 V
# uthivruuhvarak UH0 TH IH0 V R UW1 HH V AH0 R AH0 K
# uthivtakoo UH0 TH IH0 V T AH0 K OW1
# uthvuuyti UH0 TH V UW1 Y T IH0
# uthvuuytih UH0 TH V UW1 Y T IH0 HH
# uthxuunatih UH0 TH HH UW1 N AH0 T IH0 HH
# uturaati UH0 T UH0 R AA1 T IH0
# uuhyan UW1 HH Y AH0 N
# uum UW1 M
# uumkun UW1 M K UH0 N
# uumpan UW1 M P AH0 N
# uupiipha UW1 P IY1 P HH AH0
# uurihaan UW1 R IH0 HH AA1 N
# uuth UW1 TH
# uvaaram UH0 V AA1 R AH0 M
# uvaaramat UH0 V AA1 R AH0 M AH0 T
# uvaarameesh UH0 V AA1 R AH0 M EY1 SH
# uvarariihvutih UH0 V AH0 R AH0 R IY1 HH V UH0 T IH0 HH
# uvasip UH0 V AH0 SH IH0 P
# uvathiivtih UH0 V AH0 TH IY1 V T IH0 HH
# uvishtaantih UH0 V IH0 SH T AA1 N T IH0 HH
# uvoonfuruk UH0 V OW1 N F UH0 R UH0 K
# uvoonfurukatih UH0 V OW1 N F UH0 R UH0 K AH0 T IH0 HH
# uvoonsipreeheen UH0 V OW1 N SH IH0 P R EY1 HH EY1 N
# uvoonupuk UH0 V OW1 N UH0 P UH0 K
# uvooruraa UH0 V OW1 R UH0 R AA1
# uxraah UH0 HH R AA1 HH
# uxraratih UH0 HH R AH0 R AH0 T IH0 HH
# uxus UH0 HH UH0 SH
# uxuseen UH0 HH UH0 SH EY1 N
# uxuti UH0 HH UH0 T IH0
# uxutih UH0 HH UH0 T IH0 HH
# uyruuhsip UH0 Y R UW1 HH SH IH0 P
# uyukukuhiti UH0 Y UH0 K UH0 K UH0 HH IH0 T IH0
# uyuunkat UH0 Y UW1 N K AH0 T
# uyuupha UH0 Y UW1 P HH AH0
# va V AH0
# va2aram V AA1 R AH0 M
# vaa V AA1
# vaaqii V AA1 T IY1
# vaaram V AA1 R AH0 M
# vaaramas V AA1 R AH0 M AH0 SH
# vaas V AA1 SH
# vaqahup V AH0 T AH0 HH UH0 P
# vaqaraar V AH0 T AH0 R AA1 R
# vaqaraas V AH0 T AH0 R AA1 SH
# vasihkam V AH0 SH IH0 HH K AH0 M
# vaxa1raha V AH0 HH AH0 R AH0 HH AH0
# ve2enka V EY1 N K AH0
# vee V EY1
# veeniichva V EY1 N IY1 CH V AH0
# vikayav V IH0 K AH0 Y AH0 V
# vina V IH0 N AH0
# viri V IH0 R IH0
# viriva V IH0 R IH0 V AH0
# virusur V IH0 R UH0 SH UH0 R
# vishtaantih V IH0 SH T AA1 N T IH0 HH
# vishvankaam V IH0 SH V AH0 N K AA1 M
# vookuphaanik V OW1 K UH0 P HH AA1 N IH0 K
# vookxiipshiprin V OW1 K HH IY1 P SH IH0 P R IH0 N
# voom V OW1 M
# voonfuruk V OW1 N F UH0 R UH0 K
# voonupuk V OW1 N UH0 P UH0 K
# vooqeeh V OW1 T EY1 HH
# vu1ra V UH0 R AH0
# vuhapithxahar V UH0 HH AH0 P IH0 TH HH AH0 HH AH0 R
# vura V UH0 R AH0
# vurathuukkichpaqaahputhiinati V UH0 R AH0 TH UW1 K K IH0 CH P AH0 T AA1 HH P UH0 TH IY1 N AH0 T IH0
# vurava V UH0 R AH0 V AH0
# vuraxay V UH0 R AH0 HH AH0 Y
# xa1kaan HH AH0 K AA1 N
# xa1kan HH AH0 K AH0 N
# xaapki HH AA1 P K IH0
# xaat HH AA1 T
# xaatik HH AA1 T IH0 K
# xakaan HH AH0 K AA1 N
# xakkan HH AH0 K K AH0 N
# xan HH AH0 N
# xana1h HH AH0 N AH0 HH
# xanahich HH AH0 N AH0 HH IH0 CH
# xanahichvari HH AH0 N AH0 HH IH0 CH V AH0 R IH0
# xanchiifich HH AH0 N CH IY1 F IH0 CH
# xankiit HH AH0 N K IY1 T
# xanpuchiniishveenach HH AH0 N P UH0 CH IH0 N IY1 SH V EY1 N AH0 CH
# xara HH AH0 R AH0
# xas HH AH0 SH
# xasik HH AH0 SH IH0 K
# xaspuya HH AH0 SH P UH0 Y AH0
# xay HH AH0 Y
# xayfaat HH AH0 Y F AA1 T
# xrah HH R AH0 HH
# xrara HH R AH0 R AH0
# xrupeesh HH R UH0 P EY1 SH
# xu1tik HH UH0 T IH0 K
# xuntapan HH UH0 N T AH0 P AH0 N
# xuriha HH UH0 R IH0 HH AH0
# xus HH UH0 SH
# xutihara HH UH0 T IH0 HH AH0 R AH0
# xuun HH UW1 N
# xuus HH UW1 SH
# xviipha HH V IY1 P HH AH0
# xyar HH Y AH0 R
# ya Y AH0
# ya1xa Y AH0 HH AH0
# yaamach Y AA1 M AH0 CH
# yaamachas Y AA1 M AH0 CH AH0 SH
# yaamachasheesh Y AA1 M AH0 CH AH0 SH EY1 SH
# yaamachheesh Y AA1 M AH0 CH HH EY1 SH
# yaamachich Y AA1 M AH0 CH IH0 CH
# yaasqara Y AA1 SH T AH0 R AH0
# yanava Y AH0 N AH0 V AH0
# yanip Y AH0 N IH0 P
# yav Y AH0 V
# yaxa Y AH0 HH AH0
# yeah Y EH0 AH0 HH
# yee Y EY1
# yeeheehee Y EY1 HH EY1 HH EY1
# yeeshiip Y EY1 SH IY1 P
# yehehehanahe Y EH0 HH EH0 HH EH0 HH AH0 N AH0 HH EH0
# yichakanach Y IH0 CH AH0 K AH0 N AH0 CH
# yiim Y IY1 M
# yiiv Y IY1 V
# yiivanihich Y IY1 V AH0 N IH0 HH IH0 CH
# yith Y IH0 TH
# yitha Y IH0 TH AH0
# yootva Y OW1 T V AH0
# youknow Y OW0 UH0 K N OW0 W
# yruhunih Y R UH0 HH UH0 N IH0 HH
# yufish Y UH0 F IH0 SH
# yufishhi Y UH0 F IH0 SH HH IH0
# yukukuh Y UH0 K UH0 K UH0 HH
# yupsitanich Y UH0 P SH IH0 T AH0 N IH0 CH
# yupthukirar Y UH0 P TH UH0 K IH0 R AH0 R
# yuraschishiih Y UH0 R AH0 SH CH IH0 SH IY1 HH
# yuuhva Y UW1 HH V AH0
# yuum Y UW1 M
# yuuphi Y UW1 P HH IH0
